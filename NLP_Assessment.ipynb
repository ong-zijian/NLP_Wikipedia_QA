# %% [markdown]
# # NLP Assessment
# Name: Ong Zi Jian
#
# The 2 sample CSV files generated are from the 'World War 2" Wikipedia page. The link can be found in step 2.
#
# ### Task:
# 1. Take in a Wikipedia URL input
# 2. Scrap the webpage for the information
# 3. Clean the data
# 4. Generate questions and create answer
# 5. Evaluate the questions and answers
#
# ### Running the notebook:
# - Run all the steps from 1 - 9
# - Run the cells in sequence from top to bottom.
# - Ensure that the dependencies are installed before moving on since the dependencies are for the next cell to work.
# - Ensure that correct inputs are given when prompt, like the the prompt for url.
#
# ### Troubleshoot:
# - Restart all runtime and run again
# - ensure that dependencies are properly installed before moving on

# %%
# Step 1: Web URL
urlFinal = input("What's the Wikipedia URL? ")
print(urlFinal)
# Out:
# What's the Wikipedia URL? https://en.wikipedia.org/wiki/Quantum_computing
# https://en.wikipedia.org/wiki/Quantum_computing

# %% [markdown]
# ## Using beautiful Soup library
# We will be using both Beautiful Soup and requests together. When cleaning the data, there are many different types of option to consider to get a truly clean data. We have simplified to 2 types for easy cleaning.
# 1. Normal Text Document: This will be ensuring that all the simple text do not contain any unnnecessary symbols, words, letters, etc.
# 2. Math Formula: I used the Quantum Physics Wikipedia page to test. I have identified the class type to be `mwe-math-element`. It should be noted that I was not able to truly check all wiki pages to ascertain that all math element follows this class naming convention.
#
#
# The requests library is used as it can very simply pull details from the webpages with just a few lines of code. Beautiful Soup is another powerful tool to clean away the html tags and return the text.

# %%
# Step 2: Beautiful Soup and Request
from bs4 import BeautifulSoup
import requests
import re

# Test URL
url = "https://en.wikipedia.org/wiki/Quantum_computing"
url2 = "https://en.wikipedia.org/wiki/World_War_II"
response = requests.get(urlFinal)

# Check response and return error if url cannot be accessed
if response.status_code == 200:
    #If working, continue with the beautiful soup parser
    soup = BeautifulSoup(response.content, "html.parser")

    ####### Basic clean up of non-text inputs and references ###########
    ## Remove images
    for img in soup.find_all("img"):
        img.extract()
    ## Remove tables
    for table in soup.find_all("table"):
        table.extract()
    ## Remove lists
    for ul in soup.find_all("ul"):
        ul.extract()
    ## Remove reference numbers
    for sup in soup.find_all("sup", {"class": "reference"}):
        sup.extract()
    ## Remove reference links
    for a in soup.find_all("a", {"href": re.compile(r"^#cite_note-.*")}):
        a.extract()
    ## Remove HTML entities
    for entity in soup.find_all("span", {"class": "html_entity"}):
        entity.replace_with(entity.text)

    ####### Remove
    ## Remove notes and citations
    for section in soup.select(".reflist"):
        section.extract()
    for section in soup.select(".reflist+*"):
        section.extract()
    ## Remove the headers
    header_tags = ['title', 'header', 'h2', 'h3', 'h4', 'h5', 'h6']
    for tag in header_tags:
        for header in soup.find_all(tag):
            header.extract()
    # Remove the nav
    for nav in soup.select("nav"):
      nav.extract()
    # # Remove "See also" and "Sister projects" sections
    sister_projects_section = soup.find("div", {"class": "reflist-sister"})
    if sister_projects_section:
        sister_projects_section.extract()

    ######## find all div elements with role="note" ############
    note_divs = soup.find_all("div", {"role": "note"})
    # loop through the divs
    for div in note_divs:
        # Remove the "See also" section
        if "See also" in div.get_text():
            div.extract()
        # Remove the "Main Article" section
        if "Main article" in div.get_text():
            div.extract()

    # Find the element by its id and remove it
    element = soup.find(id="siteSub")
    element.decompose()
    
    # Find the element by its id and remove it
    element = soup.find(id="catlinks")
    element.decompose() 

    # Remove all elements with class
    for tag in soup.find_all(class_='side-box-abovebelow'):
        tag.decompose()

    # Remove all elements with class for math element
    for tag in soup.find_all(class_='mwe-math-element'):
        tag.decompose()



    ########## find all a elements with `a` tag #####################
    note_a = soup.find_all("a")
    # loop through the divs and remove the "See Also" section
    for a in note_a:
        if "Jump to content" in a.get_text():
            a.extract()


    text = soup.get_text()

    text = text.replace("\xa0II", "")
    text = text.replace("\xa0", "")

    # Remove empty lines
    lines = [line for line in text.splitlines() if line.strip()]
    text = '\n'.join(lines)

    # Turning all the string to lower case
    text = re.sub('[A-Z]', lambda x: x.group(0).lower(), text)


    # More regex
    ## Remove mathematical formulas enclosed in curly braces
    text = re.sub(r'{\\displaystyle.*?}', '', text)
    ## Remove mathematical formulas enclosed in dollar signs
    text = re.sub(r'\$.*?\$', '', text)
    ## Remove any remaining mathematical symbols
    text = re.sub(r'\w*\d+\w*', '', text)

    # Remove the retrieved from
    text = re.sub(r'retrieved from.*', '', text)

    text = re.sub(r'\.{3}', '', text)



    print(text)
    
else:
    print("Error retrieving content from website")
# Out:
# technology that uses quantum mechanics
#  ibm q system one, a quantum computer with  superconducting qubits
# a quantum computer is a computer that exploits quantum mechanical phenomena.
# at small scales, physical matter exhibits properties of both particles and waves, and quantum computing leverages this behavior using specialized hardware.
# classical physics cannot explain the operation of these quantum devices, and a scalable quantum computer could perform some calculations exponentially faster than any modern "classical" computer.
# in particular, a large-scale quantum computer could break widely used encryption schemes and aid physicists in performing physical simulations; however, the current state of the art is still largely experimental and impractical.
# the basic unit of information in quantum computing is the qubit, similar to the bit in traditional digital electronics. unlike a classical bit, a qubit can exist in a superposition of its two "basis" states, which loosely means that it is in both states simultaneously. when measuring a qubit, the result is a probabilistic output of a classical bit. if a quantum computer manipulates the qubit in a particular way, wave interference effects can amplify the desired measurement results. the design of quantum algorithms involves creating procedures that allow a quantum computer to perform calculations efficiently.
# physically engineering high-quality qubits has proven challenging.
# if a physical qubit is not sufficiently isolated from its environment, it suffers from quantum decoherence, introducing noise into calculations.
# national governments have invested heavily in experimental research that aims to develop scalable qubits with longer coherence times and lower error rates.
# two of the most promising technologies are superconductors (which isolate an electrical current by eliminating electrical resistance) and ion traps (which confine a single atomic particle using electromagnetic fields).
# any computational problem that can be solved by a classical computer can also be solved by a quantum computer. conversely, any problem that can be solved by a quantum computer can also be solved by a classical computer, at least in principle given enough time. in other words, quantum computers obey the church–turing thesis. this means that while quantum computers provide no additional advantages over classical computers in terms of computability, quantum algorithms for certain problems have significantly lower time complexities than corresponding known classical algorithms. notably, quantum computers are believed to be able to solve certain problems quickly that no classical computer could solve in any feasible amount of time—a feat known as "quantum supremacy." the study of the computational complexity of problems with respect to quantum computers is known as quantum complexity theory.
# for a chronological guide, see timeline of quantum computing and communication.
#  the mach–zehnder interferometer shows that photons can exhibit wave-like interference.
# for many years, the fields of quantum mechanics and computer science formed distinct academic communities. modern quantum theory developed in the  to explain the wave–particle duality observed at atomic scales, and digital computers emerged in the following decades to replace human computers for tedious calculations. both disciplines had practical applications during world war ii; computers played a major role in wartime cryptography, and quantum physics was essential for the nuclear physics used in the manhattan project.
# as physicists applied quantum mechanical models to computational problems and swapped digital bits for qubits, the fields of quantum mechanics and computer science began to converge.
# in , paul benioff introduced the quantum turing machine, which uses quantum theory to describe a simplified computer.
# when digital computers became faster, physicists faced an exponential increase in overhead when simulating quantum dynamics, prompting yuri manin and richard feynman to independently suggest that hardware based on quantum phenomena might be more efficient for computer simulation.
# in a  paper, charles bennett and gilles brassard applied quantum theory to cryptography protocols and demonstrated that quantum key distribution could enhance information security.
#  peter shor (pictured here in ) showed in  that a scalable quantum computer would be able to break rsa encryption.
# quantum algorithms then emerged for solving oracle problems, such as deutsch's algorithm in , the bernstein–vazirani algorithm in , and simon's algorithm in .
# these algorithms did not solve practical problems, but demonstrated mathematically that one could gain more information by querying a black box with a quantum state in superposition, sometimes referred to as quantum parallelism.
# peter shor built on these results with his  algorithms for breaking the widely used rsa and diffie–hellman encryption protocols, which drew significant attention to the field of quantum computing.
# in , grover's algorithm established a quantum speedup for the widely applicable unstructured search problem. the same year, seth lloyd proved that quantum computers could simulate quantum systems without the exponential overhead present in classical simulations, validating feynman's  conjecture.
# over the years, experimentalists have constructed small-scale quantum computers using trapped ions and superconductors.
# in , a two-qubit quantum computer demonstrated the feasibility of the technology, and subsequent experiments have increased the number of qubits and reduced error rates.
# in , google ai and nasa announced that they had achieved quantum supremacy with a -qubit machine, performing a computation that is impossible for any classical computer. however, the validity of this claim is still being actively researched.
# the threshold theorem shows how increasing the number of qubits can mitigate errors, yet fully fault-tolerant quantum computing remains "a rather distant dream".
# according to some researchers, noisy intermediate-scale quantum (nisq) machines may have specialized uses in the near future, but noise in quantum gates limits their reliability.
# in recent years, investment in quantum computing research has increased in the public and private sectors.
# as one consulting firm summarized,
# investment dollars are pouring in, and quantum-computing start-ups are proliferating. while quantum computing promises to help businesses solve problems that are beyond the reach and speed of conventional high-performance computers, use cases are largely experimental and hypothetical at this early stage.
# computer engineers typically describe a modern computer's operation in terms of classical electrodynamics.
# within these "classical" computers, some components (such as semiconductors and random number generators) may rely on quantum behavior, but these components are not isolated from their environment, so any quantum information quickly decoheres.
# while programmers may depend on probability theory when designing a randomized algorithm, quantum mechanical notions like superposition and interference are largely irrelevant for program analysis.
# quantum programs, in contrast, rely on precise control of coherent quantum systems. physicists describe these systems mathematically using linear algebra. complex numbers model probability amplitudes, vectors model quantum states, and matrices model the operations that can be performed on these states. programming a quantum computer is then a matter of composing operations in such a way that the resulting program computes a useful result in theory and is implementable in practice.
# the prevailing model of quantum computation describes the computation in terms of a network of quantum logic gates. this model is a complex linear-algebraic generalization of boolean circuits.
# the qubit serves as the basic unit of quantum information.
# it represents a two-state system, just like a classical bit, except that it can exist in a superposition of its two states.
# in one sense, a superposition is like a probability distribution over the two values.
# however, a quantum computation can be influenced by both values at once, inexplicable by either state individually.
# in this sense, a "superposed" qubit stores both values simultaneously.
# a two-dimensional vector mathematically represents a qubit state. physicists typically use dirac notation for quantum mechanical linear algebra, writing |ψ⟩ 'ket psi' for a vector labeled ψ. because a qubit is a two-state system, any qubit state takes the form α|⟩ + β|⟩, where |⟩ and |⟩ are the standard basis states, and α and β are the probability amplitudes. if either α or β is zero, the qubit is effectively a classical bit; when both are nonzero, the qubit is in superposition. such a quantum state vector acts similarly to a (classical) probability vector, with one key difference: unlike probabilities, probability amplitudes are not necessarily positive numbers. negative amplitudes allow for destructive wave interference.
# when a qubit is measured in the standard basis, the result is a classical bit.
# the born rule describes the norm-squared correspondence between amplitudes and probabilities—when measuring a qubit α|⟩ + β|⟩, the state collapses to |⟩ with probability |α|, or to |⟩ with probability |β|.
# any valid qubit state has coefficients α and β such that |α| + |β| = .
# as an example, measuring the qubit /√|⟩ + /√|⟩ would produce either |⟩ or |⟩ with equal probability.
# each additional qubit doubles the dimension of the state space.
# as an example, the vector /√|⟩ + /√|⟩ represents a two-qubit state, a tensor product of the qubit |⟩ with the qubit /√|⟩ + /√|⟩.
# this vector inhabits a four-dimensional vector space spanned by the basis vectors |⟩, |⟩, |⟩, and |⟩.
# the bell state /√|⟩ + /√|⟩ is impossible to decompose into the tensor product of two individual qubits—the two qubits are entangled because their probability amplitudes are correlated.
# in general, the vector space for an n-qubit system is -dimensional, and this makes it challenging for a classical computer to simulate a quantum one: representing a -qubit system requires storing  classical values.
# the state of this one-qubit quantum memory can be manipulated by applying quantum logic gates, analogous to how classical memory can be manipulated with classical logic gates. one important gate for both classical and quantum computation is the not gate, which can be represented by a matrix
# mathematically, the application of such a logic gate to a quantum state vector is modelled with matrix multiplication. thus
#  and .
# the mathematics of single qubit gates can be extended to operate on multi-qubit quantum memories in two important ways. one way is simply to select a qubit and apply that gate to the target qubit while leaving the remainder of the memory unaffected. another way is to apply the gate to its target only if another part of the memory is in a desired state. these two choices can be illustrated using another example. the possible states of a two-qubit quantum memory are
# the cnot gate can then be represented using the following matrix:
# as a mathematical consequence of this definition, , , , and . in other words, the cnot applies a not gate ( from before) to the second qubit if and only if the first qubit is in the state . if the first qubit is , nothing is done to either qubit.
# in summary, a quantum computation can be described as a network of quantum logic gates and measurements. however, any measurement can be deferred to the end of quantum computation, though this deferment may come at a computational cost, so most quantum circuits depict a network consisting only of quantum logic gates and no measurements.
# quantum parallelism refers to the ability of quantum computers to evaluate a function for multiple input values simultaneously. this can be achieved by preparing a quantum system in a superposition of input states, and applying a unitary transformation that encodes the function to be evaluated. the resulting state encodes the function's output values for all input values in the superposition, allowing for the computation of multiple outputs simultaneously. this property is key to the speedup of many quantum algorithms.
# further information: quantum programming
# there are a number of models of computation for quantum computing, distinguished by the basic elements in which the computation is decomposed.
#  a quantum circuit diagram implementing a toffoli gate from more primitive gates
# a quantum gate array decomposes computation into a sequence of few-qubit quantum gates. a quantum computation can be described as a network of quantum logic gates and measurements. however, any measurement can be deferred to the end of quantum computation, though this deferment may come at a computational cost, so most quantum circuits depict a network consisting only of quantum logic gates and no measurements.
# any quantum computation (which is, in the above formalism, any unitary matrix of size  over  qubits) can be represented as a network of quantum logic gates from a fairly small family of gates. a choice of gate family that enables this construction is known as a universal gate set, since a computer that can run such circuits is a universal quantum computer. one common such set includes all single-qubit gates as well as the cnot gate from above. this means any quantum computation can be performed by executing a sequence of single-qubit gates together with cnot gates. though this gate set is infinite, it can be replaced with a finite gate set by appealing to the solovay-kitaev theorem.
# a measurement-based quantum computer decomposes computation into a sequence of bell state measurements and single-qubit quantum gates applied to a highly entangled initial state (a cluster state), using a technique called quantum gate teleportation.
# an adiabatic quantum computer, based on quantum annealing, decomposes computation into a slow continuous transformation of an initial hamiltonian into a final hamiltonian, whose ground states contain the solution.
# a topological quantum computer decomposes computation into the braiding of anyons in a  lattice.
# the quantum turing machine is theoretically important but the physical implementation of this model is not feasible. all of these models of computation—quantum circuits, one-way quantum computation, adiabatic quantum computation, and topological quantum computation—have been shown to be equivalent to the quantum turing machine; given a perfect implementation of one such quantum computer, it can simulate all the others with no more than polynomial overhead. this equivalence need not hold for practical quantum computers, since the overhead of simulation may be too large to be practical.
# further information: quantum information science
# quantum cryptography could potentially fulfill some of the functions of public key cryptography. quantum-based cryptographic systems could, therefore, be more secure than traditional systems against quantum hacking.
# progress in finding quantum algorithms typically focuses on this quantum circuit model, though exceptions like the quantum adiabatic algorithm exist. quantum algorithms can be roughly categorized by the type of speedup achieved over corresponding classical algorithms.
# quantum algorithms that offer more than a polynomial speedup over the best-known classical algorithm include shor's algorithm for factoring and the related quantum algorithms for computing discrete logarithms, solving pell's equation, and more generally solving the hidden subgroup problem for abelian finite groups. these algorithms depend on the primitive of the quantum fourier transform. no mathematical proof has been found that shows that an equally fast classical algorithm cannot be discovered, although this is considered unlikely.[self-published source?] certain oracle problems like simon's problem and the bernstein–vazirani problem do give provable speedups, though this is in the quantum query model, which is a restricted model where lower bounds are much easier to prove and doesn't necessarily translate to speedups for practical problems.
# other problems, including the simulation of quantum physical processes from chemistry and solid-state physics, the approximation of certain jones polynomials, and the quantum algorithm for linear systems of equations have quantum algorithms appearing to give super-polynomial speedups and are bqp-complete. because these problems are bqp-complete, an equally fast classical algorithm for them would imply that no quantum algorithm gives a super-polynomial speedup, which is believed to be unlikely.
# some quantum algorithms, like grover's algorithm and amplitude amplification, give polynomial speedups over corresponding classical algorithms. though these algorithms give comparably modest quadratic speedup, they are widely applicable and thus give speedups for a wide range of problems. many examples of provable quantum speedups for query problems are related to grover's algorithm, including brassard, høyer, and tapp's algorithm for finding collisions in two-to-one functions, which uses grover's algorithm, and farhi, goldstone, and gutmann's algorithm for evaluating nand trees, which is a variant of the search problem.
# a notable application of quantum computation is for attacks on cryptographic systems that are currently in use. integer factorization, which underpins the security of public key cryptographic systems, is believed to be computationally infeasible with an ordinary computer for large integers if they are the product of few prime numbers (e.g., products of two -digit primes). by comparison, a quantum computer could solve this problem exponentially faster using shor's algorithm to find its factors. this ability would allow a quantum computer to break many of the cryptographic systems in use today, in the sense that there would be a polynomial time (in the number of digits of the integer) algorithm for solving the problem. in particular, most of the popular public key ciphers are based on the difficulty of factoring integers or the discrete logarithm problem, both of which can be solved by shor's algorithm. in particular, the rsa, diffie–hellman, and elliptic curve diffie–hellman algorithms could be broken. these are used to protect secure web pages, encrypted email, and many other types of data. breaking these would have significant ramifications for electronic privacy and security.
# identifying cryptographic systems that may be secure against quantum algorithms is an actively researched topic under the field of post-quantum cryptography. some public-key algorithms are based on problems other than the integer factorization and discrete logarithm problems to which shor's algorithm applies, like the mceliece cryptosystem based on a problem in coding theory. lattice-based cryptosystems are also not known to be broken by quantum computers, and finding a polynomial time algorithm for solving the dihedral hidden subgroup problem, which would break many lattice based cryptosystems, is a well-studied open problem. it has been proven that applying grover's algorithm to break a symmetric (secret key) algorithm by brute force requires time equal to roughly / invocations of the underlying cryptographic algorithm, compared with roughly  in the classical case, meaning that symmetric key lengths are effectively halved: aes- would have the same security against an attack using grover's algorithm that aes- has against classical brute-force search (see key size).
# the most well-known example of a problem that allows for a polynomial quantum speedup is unstructured search, which involves finding a marked item out of a list of  items in a database. this can be solved by grover's algorithm using  queries to the database, quadratically fewer than the  queries required for classical algorithms. in this case, the advantage is not only provable but also optimal: it has been shown that grover's algorithm gives the maximal possible probability of finding the desired element for any number of oracle lookups.
# problems that can be efficiently addressed with grover's algorithm have the following properties:
# there is no searchable structure in the collection of possible answers,
# the number of possible answers to check is the same as the number of inputs to the algorithm, and
# there exists a boolean function that evaluates each input and determines whether it is the correct answer
# for problems with all these properties, the running time of grover's algorithm on a quantum computer scales as the square root of the number of inputs (or elements in the database), as opposed to the linear scaling of classical algorithms. a general class of problems to which grover's algorithm can be applied is boolean satisfiability problem, where the database through which the algorithm iterates is that of all possible answers. an example and possible application of this is a password cracker that attempts to guess a password. breaking symmetric ciphers with this algorithm is of interest to government agencies.
# since chemistry and nanotechnology rely on understanding quantum systems, and such systems are impossible to simulate in an efficient manner classically, quantum simulation may be an important application of quantum computing. quantum simulation could also be used to simulate the behavior of atoms and particles at unusual conditions such as the reactions inside a collider.
# about % of the annual global energy output is used for nitrogen fixation to produce ammonia for the haber process in the agricultural fertilizer industry (even though naturally occurring organisms also produce ammonia). quantum simulations might be used to understand this process and increase the energy efficiency of production.
# quantum annealing relies on the adiabatic theorem to undertake calculations. a system is placed in the ground state for a simple hamiltonian, which slowly evolves to a more complicated hamiltonian whose ground state represents the solution to the problem in question. the adiabatic theorem states that if the evolution is slow enough the system will stay in its ground state at all times through the process. adiabatic optimization may be helpful for solving computational biology problems.
# since quantum computers can produce outputs that classical computers cannot produce efficiently, and since quantum computation is fundamentally linear algebraic, some express hope in developing quantum algorithms that can speed up machine learning tasks.
# for example, the quantum algorithm for linear systems of equations, or "hhl algorithm", named after its discoverers harrow, hassidim, and lloyd, is believed to provide speedup over classical counterparts. some research groups have recently explored the use of quantum annealing hardware for training boltzmann machines and deep neural networks.
# deep generative chemistry models emerge as powerful tools to expedite drug discovery. however, the immense size and complexity of the structural space of all possible drug-like molecules pose significant obstacles, which could be overcome in the future by quantum computers. quantum computers are naturally good for solving complex quantum many-body problems and thus may be instrumental in applications involving quantum chemistry. therefore, one can expect that quantum-enhanced generative models including quantum gans may eventually be developed into ultimate generative chemistry algorithms.
#  a wafer of adiabatic quantum computers
# there are a number of technical challenges in building a large-scale quantum computer. physicist david divincenzo has listed these requirements for a practical quantum computer:
# sourcing parts for quantum computers is also very difficult. superconducting quantum computers, like those constructed by google and ibm, need helium-, a nuclear research byproduct, and special superconducting cables made only by the japanese company coax co.
# the control of multi-qubit systems requires the generation and coordination of a large number of electrical signals with tight and deterministic timing resolution. this has led to the development of quantum controllers that enable interfacing with the qubits. scaling these systems to support a growing number of qubits is an additional challenge.
# one of the greatest challenges involved with constructing quantum computers is controlling or removing quantum decoherence. this usually means isolating the system from its environment as interactions with the external world cause the system to decohere. however, other sources of decoherence also exist. examples include the quantum gates, and the lattice vibrations and background thermonuclear spin of the physical system used to implement the qubits. decoherence is irreversible, as it is effectively non-unitary, and is usually something that should be highly controlled, if not avoided. decoherence times for candidate systems in particular, the transverse relaxation time  (for nmr and mri technology, also called the dephasing time), typically range between nanoseconds and seconds at low temperature. currently, some quantum computers require their qubits to be cooled to  millikelvin (usually using a dilution refrigerator) in order to prevent significant decoherence. a  study argues that ionizing radiation such as cosmic rays can nevertheless cause certain systems to decohere within milliseconds.
# as a result, time-consuming tasks may render some quantum algorithms inoperable, as attempting to maintain the state of qubits for a long enough duration will eventually corrupt the superpositions.
# these issues are more difficult for optical approaches as the timescales are orders of magnitude shorter and an often-cited approach to overcoming them is optical pulse shaping. error rates are typically proportional to the ratio of operating time to decoherence time, hence any operation must be completed much more quickly than the decoherence time.
# as described in the threshold theorem, if the error rate is small enough, it is thought to be possible to use quantum error correction to suppress errors and decoherence. this allows the total calculation time to be longer than the decoherence time if the error correction scheme can correct errors faster than decoherence introduces them. an often-cited figure for the required error rate in each gate for fault-tolerant computation is −, assuming the noise is depolarizing.
# meeting this scalability condition is possible for a wide range of systems. however, the use of error correction brings with it the cost of a greatly increased number of required qubits. the number required to factor integers using shor's algorithm is still polynomial, and thought to be between l and , where l is the number of digits in the number to be factored; error correction algorithms would inflate this figure by an additional factor of l. for a -bit number, this implies a need for about  bits without error correction. with error correction, the figure would rise to about  bits. computation time is about  or about  steps and at , about  seconds. however, other careful estimates lower the qubit count to  for factorizing ,-bit integer in  months on a trapped-ion quantum computer.
# another approach to the stability-decoherence problem is to create a topological quantum computer with anyons, quasi-particles used as threads, and relying on braid theory to form stable logic gates.
# quantum supremacy is a term coined by john preskill referring to the engineering feat of demonstrating that a programmable quantum device can solve a problem beyond the capabilities of state-of-the-art classical computers. the problem need not be useful, so some view the quantum supremacy test only as a potential future benchmark.
# in october , google ai quantum, with the help of nasa, became the first to claim to have achieved quantum supremacy by performing calculations on the sycamore quantum computer more than ,, times faster than they could be done on summit, generally considered the world's fastest computer. this claim has been subsequently challenged: ibm has stated that summit can perform samples much faster than claimed, and researchers have since developed better algorithms for the sampling problem used to claim quantum supremacy, giving substantial reductions to the gap between sycamore and classical supercomputers and even beating it.
# in december , a group at ustc implemented a type of boson sampling on  photons with a photonic quantum computer, jiuzhang, to demonstrate quantum supremacy. the authors claim that a classical contemporary supercomputer would require a computational time of  million years to generate the number of samples their quantum processor can generate in  seconds.
# on november , , at the quantum computing summit, ibm presented a -qubit microprocessor named ibm eagle.
# some researchers have expressed skepticism that scalable quantum computers could ever be built, typically because of the issue of maintaining coherence at large scales, but also for other reasons.
# bill unruh doubted the practicality of quantum computers in a paper published in . paul davies argued that a -qubit computer would even come into conflict with the cosmological information bound implied by the holographic principle. skeptics like gil kalai doubt that quantum supremacy will ever be achieved. physicist mikhail dyakonov has expressed skepticism of quantum computing as follows:
# "so the number of continuous parameters describing the state of such a useful quantum computer at any given moment must be about  could we ever learn to control the more than  continuously variable parameters defining the quantum state of such a system? my answer is simple. no, never."
# for physically implementing a quantum computer, many different candidates are being pursued, among them (distinguished by the physical system used to realize the qubits):
# the large number of candidates demonstrates that quantum computing, despite rapid progress, is still in its infancy.
# further information: computability theory
# any computational problem solvable by a classical computer is also solvable by a quantum computer. intuitively, this is because it is believed that all physical phenomena, including the operation of classical computers, can be described using quantum mechanics, which underlies the operation of quantum computers.
# conversely, any problem solvable by a quantum computer is also solvable by a classical computer. it is possible to simulate both quantum and classical computers manually with just some paper and a pen, if given enough time. more formally, any quantum computer can be simulated by a turing machine. in other words, quantum computers provide no additional power over classical computers in terms of computability. this means that quantum computers cannot solve undecidable problems like the halting problem, and the existence of quantum computers does not disprove the church–turing thesis.
# while quantum computers cannot solve any problems that classical computers cannot already solve, it is suspected that they can solve certain problems faster than classical computers. for instance, it is known that quantum computers can efficiently factor integers, while this is not believed to be the case for classical computers.
# the class of problems that can be efficiently solved by a quantum computer with bounded error is called bqp, for "bounded error, quantum, polynomial time". more formally, bqp is the class of problems that can be solved by a polynomial-time quantum turing machine with an error probability of at most /. as a class of probabilistic problems, bqp is the quantum counterpart to bpp ("bounded error, probabilistic, polynomial time"), the class of problems that can be solved by polynomial-time probabilistic turing machines with bounded error. it is known that  and is widely suspected that , which intuitively would mean that quantum computers are more powerful than classical computers in terms of time complexity.
#  the suspected relationship of bqp to several classical complexity classes
# the exact relationship of bqp to p, np, and pspace is not known. however, it is known that ; that is, all problems that can be efficiently solved by a deterministic classical computer can also be efficiently solved by a quantum computer, and all problems that can be efficiently solved by a quantum computer can also be solved by a deterministic classical computer with polynomial space resources. it is further suspected that bqp is a strict superset of p, meaning there are problems that are efficiently solvable by quantum computers that are not efficiently solvable by deterministic classical computers. for instance, integer factorization and the discrete logarithm problem are known to be in bqp and are suspected to be outside of p. on the relationship of bqp to np, little is known beyond the fact that some np problems that are believed not to be in p are also in bqp (integer factorization and the discrete logarithm problem are both in np, for example). it is suspected that ; that is, it is believed that there are efficiently checkable problems that are not efficiently solvable by a quantum computer. as a direct consequence of this belief, it is also suspected that bqp is disjoint from the class of np-complete problems (if an np-complete problem were in bqp, then it would follow from np-hardness that all problems in np are in bqp).
# the relationship of bqp to the basic classical complexity classes can be summarized as follows:
# it is also known that bqp is contained in the complexity class  (or more precisely in the associated class of decision problems ), which is a subclass of pspace.
# it has been speculated that further advances in physics could lead to even faster computers. for instance, it has been shown that a non-local hidden variable quantum computer based on bohmian mechanics could implement a search of an n-item database in at most  steps, a slight speedup over grover's algorithm, which runs in  steps. note, however, that neither search method would allow quantum computers to solve np-complete problems in polynomial time. theories of quantum gravity, such as m-theory and loop quantum gravity, may allow even faster computers to be built. however, defining computation in these theories is an open problem due to the problem of time; that is, within these physical theories there is currently no obvious way to describe what it means for an observer to submit input to a computer at one point in time and then receive output at a later point in time.
# wikimedia commons has media related to quantum computer.
# wikiversity has learning resources about quantum computing
# lectures

# %% [markdown]
# ## Small final cleaning on the text
#
# We will not be using Tokenising here as we will be doing so in the Flan-T5 below. Stemming and Stop Word removal will also not be performed as it is not required for Flan-T5.
#
# For this scenario, we are not removing the punctuations as we are splitting the body of text into sentences, thus we need the ending punctuation to split the sentences.

# %%
# Step 3: Final clean up
import re

# Split the text into sentences based on punctuation marks
sentences = re.split(r'[.!?]+', text)

# Remove leading and trailing white space from each sentence
sentences = [sentence.strip() for sentence in sentences]

# Remove any empty sentences from the list
sentences = list(filter(None, sentences))

print(sentences)
# Out:
# ['technology that uses quantum mechanics\n ibm q system one, a quantum computer with  superconducting qubits\na quantum computer is a computer that exploits quantum mechanical phenomena', 'at small scales, physical matter exhibits properties of both particles and waves, and quantum computing leverages this behavior using specialized hardware', 'classical physics cannot explain the operation of these quantum devices, and a scalable quantum computer could perform some calculations exponentially faster than any modern "classical" computer', 'in particular, a large-scale quantum computer could break widely used encryption schemes and aid physicists in performing physical simulations; however, the current state of the art is still largely experimental and impractical', 'the basic unit of information in quantum computing is the qubit, similar to the bit in traditional digital electronics', 'unlike a classical bit, a qubit can exist in a superposition of its two "basis" states, which loosely means that it is in both states simultaneously', 'when measuring a qubit, the result is a probabilistic output of a classical bit', 'if a quantum computer manipulates the qubit in a particular way, wave interference effects can amplify the desired measurement results', 'the design of quantum algorithms involves creating procedures that allow a quantum computer to perform calculations efficiently', 'physically engineering high-quality qubits has proven challenging', 'if a physical qubit is not sufficiently isolated from its environment, it suffers from quantum decoherence, introducing noise into calculations', 'national governments have invested heavily in experimental research that aims to develop scalable qubits with longer coherence times and lower error rates', 'two of the most promising technologies are superconductors (which isolate an electrical current by eliminating electrical resistance) and ion traps (which confine a single atomic particle using electromagnetic fields)', 'any computational problem that can be solved by a classical computer can also be solved by a quantum computer', 'conversely, any problem that can be solved by a quantum computer can also be solved by a classical computer, at least in principle given enough time', 'in other words, quantum computers obey the church–turing thesis', 'this means that while quantum computers provide no additional advantages over classical computers in terms of computability, quantum algorithms for certain problems have significantly lower time complexities than corresponding known classical algorithms', 'notably, quantum computers are believed to be able to solve certain problems quickly that no classical computer could solve in any feasible amount of time—a feat known as "quantum supremacy', '" the study of the computational complexity of problems with respect to quantum computers is known as quantum complexity theory', 'for a chronological guide, see timeline of quantum computing and communication', 'the mach–zehnder interferometer shows that photons can exhibit wave-like interference', 'for many years, the fields of quantum mechanics and computer science formed distinct academic communities', 'modern quantum theory developed in the  to explain the wave–particle duality observed at atomic scales, and digital computers emerged in the following decades to replace human computers for tedious calculations', 'both disciplines had practical applications during world war ii; computers played a major role in wartime cryptography, and quantum physics was essential for the nuclear physics used in the manhattan project', 'as physicists applied quantum mechanical models to computational problems and swapped digital bits for qubits, the fields of quantum mechanics and computer science began to converge', 'in , paul benioff introduced the quantum turing machine, which uses quantum theory to describe a simplified computer', 'when digital computers became faster, physicists faced an exponential increase i ...

# %% [markdown]
# ## Q-A Model
#
# I will be using the transformer library for the NLP work. I firstly generated the possible questions by iterating the list of sentences. With the generated questions, we will be able to answer them using the pipeline QA model, then Flan-T5 in the next few cells. We will also feed the context which is the sentence itself. From there, we extract the answer and score.

# %%
# Step 4: Importing libraries
# Install the dependencies using PIP
# !pip install transformers
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (4.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (0.1.98)

# %% [markdown]
# ## Generate the questions and predict the answer
# Before I jump into using Flan-T5, I will use the `question-generation` model to generate the questions from each line.
#
# I then used BERT to get the answer for the question. With BERT I was able to add the context, which I used the main sentence as the context. I then put all the important information into a dictionary.
#
# BERT is not necessary the fastest for this scenario. My sample data from World War 2 wiki page takes anywhere from 15 to more than 20 mins when using the standard resource on Google Colab. We will be trying out Flan-T5 in the later cells

# %%
# Step 5: Run the model using BERT 
from transformers import pipeline
from transformers import AutoModelForQuestionAnswering, AutoTokenizer

# Question Generator
generator = pipeline(model="mrm8488/t5-base-finetuned-question-generation-ap")

# Load the question answering model and tokenizer
model = AutoModelForQuestionAnswering.from_pretrained("bert-large-uncased-whole-word-masking-finetuned-squad")
tokenizer = AutoTokenizer.from_pretrained("bert-large-uncased-whole-word-masking-finetuned-squad")

# Load the question answering pipeline with the specified model
qa = pipeline("question-answering", model=model, tokenizer=tokenizer)

qa_dict = {"Question": ["Answer", "Context", "Score"]}

for sentence in sentences:
  context = sentence
  # Generate Question
  qn = generator("answer:"+sentence)
  question = qn[0]["generated_text"].replace("question: ", "")
  

  # Do QA and find results
  context = sentence
  result = qa(question=question, context=context)
  print(result['answer'])
  qa_dict[question] = [result["answer"], sentence, result["score"]]

print(qa_dict)
# Out:
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# a computer that exploits quantum mechanical phenomena
# using specialized hardware
# could perform some calculations exponentially faster than any modern "classical" computer
# break widely used encryption schemes and aid physicists in performing physical simulations
# the basic unit of information
# can exist in a superposition of its two "basis" states
# a probabilistic output
# amplify
# creating procedures that allow a quantum computer to perform calculations efficiently
# physically engineering high-quality qubits
# it suffers from quantum decoherence
# error rates
# superconductors
# any computational problem
# a classical computer
# obey
# provide no additional advantages over classical computers
# quantum computers are believed to be able to solve certain problems quickly
# quantum complexity theory
# chronological guide
# photons can exhibit wave-like interference
# many years
# modern quantum theory
# essential
# began to converge
# quantum turing machine
# when digital computers became faster
# quantum key distribution could enhance information security
# a scalable quantum computer would be able to break rsa encryption
# deutsch's algorithm
# mathematically that one could gain more information
# breaking the widely used rsa and diffie–hellman encryption protocols
# established a quantum speedup
# the same year, seth lloyd proved that quantum computers could simulate quantum systems
# using trapped ions and superconductors
# a two-qubit quantum computer
# quantum supremacy
# still being actively researched
# how increasing the number of qubits can mitigate errors
# noise in quantum gates limits their reliability
# investment in quantum computing research has increased
# investment dollars
# experimental and hypothetical
# in terms of classical electrodynamics
# these components are not isolated from their environment
# largely irrelevant
# precise control of coherent quantum systems
# mathematically using linear algebra
# complex numbers model probability amplitudes, vectors model quantum states
# programming
# the prevailing model
# this model
# the basic unit of quantum information
# it can exist in a superposition of its two states
# in one sense
# a quantum computation can be influenced by both values at once
# in this sense, a "superposed
# mathematically
# dirac notation
# because a qubit is a two-state system
# both are nonzero
# similarly
# destructive wave interference
# the standard basis
# describes the norm-squared correspondence between amplitudes and probabilities
# |α| + |β| =
# either |⟩ or |⟩ with equal probability
# each additional qubit
# represents a two-qubit state
# four-dimensional vector space
# because their probability amplitudes are correlated
# representing a -qubit system requires storing  classical values
# by applying quantum logic gates
# not gate
# thus
# in two important ways
# select a qubit
# if another part of the memory is in a desired state
# another example
# the possible states of a two-qubit quantum memory
# applies a not gate
# nothing is done to either qubit
# a network of quantum logic gates and measurements
# any measurement can be deferred to the end of quantum computation
# the ability of quantum computers to evaluate a function for multiple input values simultaneously
# in a superposition of input states
# computation of multiple outputs simultaneously
# this property is key to the speedup of many quantum algorithms
# computation is decomposed
# quantum circuit diagram
# a network of quantum logic gates and measurements
# any measurement can be deferred to the end of quantum computation
# any unitary matrix of size  over  qubits
# a choice of gate family
# one common such set
# any
# finite gate set
# quantum gate teleportation
# adiabatic quantum computer
# braiding of anyons in a  lattice
# quantum turing machine is theoretically important
# models of computation
# need not hold
# quantum cryptography
# quantum hacking
# quantum circuit model
# classical algorithms
# shor's algorithm for factoring and the related quantum algorithms
# the primitive of the quantum fourier transform
# no mathematical proof has been found
# self-published
# do give provable speedups
# quantum algorithm for linear systems of equations
# because these problems are bqp-complete
# grover's algorithm and amplitude amplification
# they are widely applicable
# finding collisions in two-to-one functions
# attacks on cryptographic systems that are currently in use
# large integers if they are the product of few prime numbers
# g
# products
# using shor's algorithm to find its factors
# there would be a polynomial time
# factoring integers or the discrete logarithm problem
# the rsa, diffie–hellman
# to protect secure web pages
# breaking
# identifying cryptographic systems that may be secure against quantum algorithms
# a problem in coding theory
# not known to be broken by quantum computers
# symmetric key lengths are effectively halved
# unstructured search
# by grover's algorithm using  queries to the database
# optimal
# there is no searchable structure in the collection of possible answers
# the database through which the algorithm iterates is that of all possible answers
# attempts to guess a password
# interest to government agencies
# systems are impossible to simulate in an efficient manner classically
# unusual conditions
# about %
# quantum
# undertake calculations
# slowly evolves to a more complicated hamiltonian
# if the evolution is slow enough the system will stay in its ground state
# adiabatic
# speed up machine learning tasks
# over classical counterparts
# training boltzmann machines and deep neural networks
# to expedite
# immense size and complexity of the structural space
# quantum computers are naturally good for solving complex quantum many-body problems
# chemistry algorithms
# a wafer
# physicist david divincenzo has listed these requirements for a practical quantum computer
# helium
# the control of multi-qubit systems
# interfacing with the qubits
# scaling these systems
# controlling or removing quantum decoherence
# isolating
# other sources of decoherence also exist
# quantum gates
# decoherence is irreversible
# dephasing time
# quantum computers require their qubits to be cooled to  millikelvin
# can nevertheless cause certain systems to decohere within milliseconds
# eventually corrupt the superpositions
# more difficult
# proportional to the ratio of operating time to decoherence time
# if the error rate is small enough
# allows the total calculation time to be longer than the decoherence time
# −
# meeting this scalability condition is possible
# a greatly increased number of required qubits
# the number required to factor integers using shor's algorithm is still polynomial
# a need for about  bits without error correction
# the figure would rise to about  bits
# computation time
# factorizing ,-bit integer in  months
# stable logic gates
# the engineering feat
# need not be useful
# google ai quantum
# ibm has stated that summit can perform samples much faster than claimed
# implemented a type of boson sampling on  photons
# a classical contemporary supercomputer would require a computational time of  million years
# a -qubit microprocessor
# maintaining coherence at large scales
# practicality
# cosmological information bound implied by the holographic principle
# quantum supremacy will ever be achieved
# skepticism of quantum computing
# my answer is simple
# no, never
# many
# any computational problem solvable by a classical computer
# which underlies the operation of quantum computers
# classical computer
# manually with just some paper and a pen
# more formally, any quantum computer can be simulated by a turing machine
# provide no additional power over classical computers
# does not
# cannot
# can efficiently factor integers
# bqp
# problems that can be solved by a polynomial-time quantum turing machine
# bpp
# it is known that  and is widely suspected that
# not known
# all problems that can be efficiently solved by a deterministic classical computer
# it is further suspected
# outside of p
# some np problems that are believed not to be in p
# it is believed that there are efficiently checkable problems
# it is also suspected
# it is also known that bqp is contained in the complexity class
# further advances in physics
# could implement a search of an n-item database in at most  steps
# neither search method
# m-theory and loop quantum gravity
# defining computation in these theories is an open problem
# wikimedia commons
# wikiversity
# {'Question': ['Answer', 'Context', 'Score'], 'What is a quantum computer?': ['a computer that exploits quantum mechanical phenomena', 'technology that uses quantum mechanics\n ibm q system one, a quantum computer with  superconducting qubits\na quantum computer is a computer that exploits quantum mechanical phenomena', 0.7963325381278992], 'Quantum computing leverages the behavior of particles and waves?': ['using specialized hardware', 'at small scales, physical matter exhibits properties of both particles and waves, and quantum computing leverages this behavior using specialized hardware', 0.26300913095474243], 'What is the problem with quantum computers?': ['could perform some calculations exponentially faster than any modern "classical" computer', 'classical physics cannot explain the operation of these quantum devices, and a scalable quantum computer could perform some calculations exponentially faster than any modern "classical" computer', 0.13283225893974304], 'What could a quantum computer do?': ['break widely used encryption schemes and aid physicists in performing physical simulations', 'in particular, a large-scale quantum computer could break widely used encryption schemes and aid physicists in performing physical simulations; however, the current state of the art is still largely experimental and impractical', 0.44566503167152405], 'What is the qubit?': ['the basic unit of quantum information', 'the qubit serves as the basic unit of quantum information', 0.5894337892532349], 'Can a qubit exist in a superposition of its two "basis': ['can exist in a superposition of its two "basis" states', 'unlike a classical bit, a qubit can exist in a superposition of its two "basis" states, which loosely means that it is in both states simultaneously', 0.10810700803995132], 'What is the result of a classical bit?': ['a probabilistic output', 'when measuring a qubit, the result is a probabilistic output of a classical bit', 0.44616860151290894], 'What is the effect of wave interference on the measurement results?': ['amplify', 'if a quantum computer manipulates the qubit in a particular way, wave interference effects can amplify the desired measurement results', 0.7822387218475342], 'What is the process of designing quantum algorithms?': ['creating procedures that allow a quantum computer to perform calculations efficiently', 'the design of quantum algorithms involves creating procedures that allow a quantum computer to perform calculations efficiently', 0.7362918853759766], 'What has proved challenging in the past?': ['physically engineering high-quality qubits', 'physically engineering high-quality qubits has proven challenging', 0.3297520875930786], 'What happens to a physical qubit if it is not isolated from its environment': ['it suffers from quantum decoherence', 'if a physical qubit is not sufficiently isolated from its environment, it suffers from quantum decoherence, introducing noise into calculations', 0.4567590653896332], 'What has been the goal of qubits with longer coherence times and lower': ['error rates', 'national governments have invested heavily in experimental research that aims to develop scalable qubits with longer coherence times and lower error rates', 0.6357697248458862], 'What are the two most promising technologies?': ['superconductors', 'two of the most promising technologies are superconductors (which isolate an electrical current by eliminating electrical resistance) and ion traps (which confine a single atomic particle using electromagnetic fields)', 0.008486637845635414], 'What can be solved by a quantum computer?': ['any computational problem', 'any computational problem that can be solved by a classical computer can also be solved by a quantum computer', 0.6461953520774841], 'How can any problem that can be solved by a quantum computer be solved by ': ['a classical computer', 'conversely, any problem that can be solved by a quantum computer can also be solved by a classical computer, at least i ...

# %% [markdown]
# ### Save to CSV
# The python dictionary is then converted into a Pandas dataframe. From there, I saved the file to CSV.
#
# *Note:The csv reads left to right on Excel or Google Sheet. Viewer may use a transpose on Excel to transpose it to read from top to bottom*

# %%
# Step 6: Save to CSV
# Save to CSV
import pandas as pd

# Convert dictionary to Pandas DataFrame
df = pd.DataFrame(qa_dict)

# Save DataFrame to CSV file
df.to_csv('qa.csv', index=False)

# %% [markdown]
# ## Using Flan-T5
# https://en.wikipedia.org/wiki/Quantum_computing
#
# I am now using Flan-T5 for its QA abilities to answer the question. I noticed that Flan-T5 takes about half the time as compared to using pipline.
#
# I will evaluate the Question and Answers using `rouge_score`. The reason for using rouge score as it is offers more parameters than F1 or Bleu and compares the precision and recall.

# %%
# Step 7: Install Rouge
# We will be installing rouge_score for the evaluation later
# !pip install rouge_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.9/dist-packages (0.1.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.9/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from rouge_score) (1.22.4)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.9/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk->rouge_score) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->rouge_score) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->rouge_score) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk->rouge_score) (4.65.0)

# %%
# Step 8: Using Flan-T5 to answer
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from transformers import pipeline
from rouge_score import rouge_scorer

# Question Generator
generator = pipeline(model="mrm8488/t5-base-finetuned-question-generation-ap")

# Flan-T5
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-small")
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-small")

# Rouge scorer
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2'], use_stemmer=True)

# Declare qns_list2 dictionary and add the header
qa_dict_t5 = {"Question": ["Answer", "Sentence", "Rouge-1(Precision)", "Rouge-1(Recall)", "Rouge-1(fmeasure)", "Rouge-2(Precision)", "Rouge-2(Recall)", "Rouge-2(fmeasure)"]}

# Generate list of questions
for sentence in sentences:
  # Generate Question
  qn = generator("answer:"+sentence)
  question = qn[0]["generated_text"].replace("question: ", "")

  # answer
  t5query = f"""Question: "{question}". Context: "{sentence}" """
  inputs = tokenizer(t5query, return_tensors="pt")
  outputs = model.generate(**inputs)
  answer = tokenizer.batch_decode(outputs, skip_special_tokens=True)

  # Evaluate accuracy of generated question-answer pair using rouge_score
  reference = sentence  
  candidate = answer
  reference_str = " ".join(reference)
  candidate_str = " ".join(candidate) 
  scores = scorer.score(reference, candidate[0])
  print("Question: " + question + ", Answer: " + str(answer) + ", Rouge-1: " + str(scores['rouge1']) + ", Rouge-2: " + str(scores['rouge2']))
  qa_dict_t5[question] = [answer[0], sentence, scores['rouge1'].precision, scores['rouge1'].recall, scores['rouge1'].fmeasure, scores['rouge2'].precision, scores['rouge2'].recall, scores['rouge2'].fmeasure]


print(qa_dict_t5)
# Out:
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Question: What is a quantum computer?, Answer: ['a computer that exploits quantum mechanical phenomena'], Rouge-1: Score(precision=1.0, recall=0.2692307692307692, fmeasure=0.42424242424242425), Rouge-2: Score(precision=1.0, recall=0.24, fmeasure=0.3870967741935484)
# Question: Quantum computing leverages the behavior of particles and waves?, Answer: ['physical matter exhibits properties'], Rouge-1: Score(precision=1.0, recall=0.19047619047619047, fmeasure=0.32), Rouge-2: Score(precision=1.0, recall=0.15, fmeasure=0.2608695652173913)
# Question: What is the problem with quantum computers?, Answer: ['a scalable quantum computer could perform some calculations exponentially faster than any modern "classical'], Rouge-1: Score(precision=1.0, recall=0.5384615384615384, fmeasure=0.7000000000000001), Rouge-2: Score(precision=1.0, recall=0.52, fmeasure=0.6842105263157895)
# Question: What could a quantum computer do?, Answer: ['perform physical simulations'], Rouge-1: Score(precision=1.0, recall=0.09090909090909091, fmeasure=0.16666666666666669), Rouge-2: Score(precision=1.0, recall=0.0625, fmeasure=0.11764705882352941)
# Question: What is the qubit?, Answer: ['quantum computing'], Rouge-1: Score(precision=1.0, recall=0.10526315789473684, fmeasure=0.1904761904761905), Rouge-2: Score(precision=1.0, recall=0.05555555555555555, fmeasure=0.10526315789473684)
# Question: Can a qubit exist in a superposition of its two "basis, Answer: ['unlike a classical bit'], Rouge-1: Score(precision=1.0, recall=0.15384615384615385, fmeasure=0.2666666666666667), Rouge-2: Score(precision=1.0, recall=0.12, fmeasure=0.21428571428571425)
# Question: What is the result of a classical bit?, Answer: ['probabilistic'], Rouge-1: Score(precision=1.0, recall=0.07142857142857142, fmeasure=0.13333333333333333), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is the effect of wave interference on the measurement results?, Answer: ['amplify'], Rouge-1: Score(precision=1.0, recall=0.05, fmeasure=0.09523809523809523), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is the process of designing quantum algorithms?, Answer: ['create procedures that allow a quantum computer to perform calculations efficiently'], Rouge-1: Score(precision=1.0, recall=0.6470588235294118, fmeasure=0.7857142857142858), Rouge-2: Score(precision=1.0, recall=0.625, fmeasure=0.7692307692307693)
# Question: What has proved challenging in the past?, Answer: ['high-quality qubits'], Rouge-1: Score(precision=1.0, recall=0.375, fmeasure=0.5454545454545454), Rouge-2: Score(precision=1.0, recall=0.2857142857142857, fmeasure=0.4444444444444445)
# Question: What happens to a physical qubit if it is not isolated from its environment, Answer: ['suffers from quantum decoherence'], Rouge-1: Score(precision=1.0, recall=0.2, fmeasure=0.33333333333333337), Rouge-2: Score(precision=1.0, recall=0.15789473684210525, fmeasure=0.2727272727272727)
# Question: What has been the goal of qubits with longer coherence times and lower, Answer: ['error rates'], Rouge-1: Score(precision=1.0, recall=0.09090909090909091, fmeasure=0.16666666666666669), Rouge-2: Score(precision=1.0, recall=0.047619047619047616, fmeasure=0.0909090909090909)
# Question: What are the two most promising technologies?, Answer: ['superconductors (which isolate an electrical current by eliminating electrical resistance) and ion'], Rouge-1: Score(precision=1.0, recall=0.41379310344827586, fmeasure=0.5853658536585366), Rouge-2: Score(precision=1.0, recall=0.39285714285714285, fmeasure=0.5641025641025641)
# Question: What can be solved by a quantum computer?, Answer: ['computational problem'], Rouge-1: Score(precision=1.0, recall=0.10526315789473684, fmeasure=0.1904761904761905), Rouge-2: Score(precision=1.0, recall=0.05555555555555555, fmeasure=0.10526315789473684)
# Question: How can any problem that can be solved by a quantum computer be solved by , Answer: ['classical computer'], Rouge-1: Score(precision=1.0, recall=0.07692307692307693, fmeasure=0.14285714285714288), Rouge-2: Score(precision=1.0, recall=0.04, fmeasure=0.07692307692307693)
# Question: What does the church-turing thesis say about quantum computers?, Answer: ['obey'], Rouge-1: Score(precision=1.0, recall=0.1, fmeasure=0.18181818181818182), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What does quantum computers do?, Answer: ['provide no additional advantages over classical computers'], Rouge-1: Score(precision=1.0, recall=0.21875, fmeasure=0.358974358974359), Rouge-2: Score(precision=1.0, recall=0.1935483870967742, fmeasure=0.3243243243243243)
# Question: What is quantum supremacy?, Answer: ['quantum computers'], Rouge-1: Score(precision=1.0, recall=0.06451612903225806, fmeasure=0.12121212121212122), Rouge-2: Score(precision=1.0, recall=0.03333333333333333, fmeasure=0.06451612903225806)
# Question: What is the term for the study of the computational complexity of problems with respect to quantum, Answer: ['quantum complexity theory'], Rouge-1: Score(precision=1.0, recall=0.15789473684210525, fmeasure=0.2727272727272727), Rouge-2: Score(precision=1.0, recall=0.1111111111111111, fmeasure=0.19999999999999998)
# Question: What is the timeline of quantum computing and communication?, Answer: ['chronological'], Rouge-1: Score(precision=1.0, recall=0.09090909090909091, fmeasure=0.16666666666666669), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What does the mach-zehnder interferometer show?, Answer: ['photons can exhibit wave-like interference'], Rouge-1: Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), Rouge-2: Score(precision=1.0, recall=0.45454545454545453, fmeasure=0.625)
# Question: For how long did the fields of quantum mechanics and computer science form distinct academic communities, Answer: ['many years'], Rouge-1: Score(precision=1.0, recall=0.13333333333333333, fmeasure=0.23529411764705882), Rouge-2: Score(precision=1.0, recall=0.07142857142857142, fmeasure=0.13333333333333333)
# Question: What theory was developed to explain the wave-particle duality observed at atomic, Answer: ['quantum theory'], Rouge-1: Score(precision=1.0, recall=0.06451612903225806, fmeasure=0.12121212121212122), Rouge-2: Score(precision=1.0, recall=0.03333333333333333, fmeasure=0.06451612903225806)
# Question: What was the role of quantum physics in the nuclear physics used in the man, Answer: ['computers played a major role in wartime cryptography'], Rouge-1: Score(precision=1.0, recall=0.25806451612903225, fmeasure=0.41025641025641024), Rouge-2: Score(precision=1.0, recall=0.23333333333333334, fmeasure=0.37837837837837834)
# Question: What happened to the fields of quantum mechanics and computer science?, Answer: ['began to converge'], Rouge-1: Score(precision=1.0, recall=0.11538461538461539, fmeasure=0.20689655172413793), Rouge-2: Score(precision=1.0, recall=0.08, fmeasure=0.14814814814814814)
# Question: What was the name of the machine that uses quantum theory to describe a computer?, Answer: ['quantum turing'], Rouge-1: Score(precision=1.0, recall=0.11764705882352941, fmeasure=0.21052631578947367), Rouge-2: Score(precision=1.0, recall=0.0625, fmeasure=0.11764705882352941)
# Question: Why did physicists face an exponential increase in overhead when simul, Answer: ['when digital computers became faster'], Rouge-1: Score(precision=1.0, recall=0.13157894736842105, fmeasure=0.23255813953488372), Rouge-2: Score(precision=1.0, recall=0.10810810810810811, fmeasure=0.1951219512195122)
# Question: What did charles bennett and gilles brassard demonstrate in , Answer: ['quantum theory'], Rouge-1: Score(precision=1.0, recall=0.08333333333333333, fmeasure=0.15384615384615385), Rouge-2: Score(precision=1.0, recall=0.043478260869565216, fmeasure=0.08333333333333333)
# Question: What did peter shor show in his paper?, Answer: ['a scalable quantum computer would be able to break rsa encryption'], Rouge-1: Score(precision=1.0, recall=0.5789473684210527, fmeasure=0.7333333333333334), Rouge-2: Score(precision=1.0, recall=0.5555555555555556, fmeasure=0.7142857142857143)
# Question: What was the name of the quantum algorithm?, Answer: ['bernstein–vazirani'], Rouge-1: Score(precision=1.0, recall=0.08333333333333333, fmeasure=0.15384615384615385), Rouge-2: Score(precision=1.0, recall=0.043478260869565216, fmeasure=0.08333333333333333)
# Question: What did the algorithms demonstrate?, Answer: ['mathematically that one could gain more information by querying a black box with a quantum'], Rouge-1: Score(precision=1.0, recall=0.45454545454545453, fmeasure=0.625), Rouge-2: Score(precision=1.0, recall=0.4375, fmeasure=0.6086956521739131)
# Question: What did peter shor do with the results of his work?, Answer: ['built on these results with his algorithms for breaking the widely used rsa and diffi'], Rouge-1: Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), Rouge-2: Score(precision=1.0, recall=0.4827586206896552, fmeasure=0.6511627906976745)
# Question: What was the result of grover's algorithm?, Answer: ['unstructured search'], Rouge-1: Score(precision=1.0, recall=0.13333333333333333, fmeasure=0.23529411764705882), Rouge-2: Score(precision=1.0, recall=0.07142857142857142, fmeasure=0.13333333333333333)
# Question: In what year did seth lloyd prove quantum computers could simulate quantum, Answer: ['the same year'], Rouge-1: Score(precision=1.0, recall=0.12, fmeasure=0.21428571428571425), Rouge-2: Score(precision=1.0, recall=0.08333333333333333, fmeasure=0.15384615384615385)
# Question: How have quantum computers been constructed?, Answer: ['small-scale quantum computers using trapped ions and superconductors'], Rouge-1: Score(precision=1.0, recall=0.6, fmeasure=0.7499999999999999), Rouge-2: Score(precision=1.0, recall=0.5714285714285714, fmeasure=0.7272727272727273)
# Question: What was the first experiment that demonstrated the feasibility of quantum computing?, Answer: ['two-qubit quantum computer'], Rouge-1: Score(precision=1.0, recall=0.16, fmeasure=0.2758620689655173), Rouge-2: Score(precision=1.0, recall=0.125, fmeasure=0.2222222222222222)
# Question: What was the name of the announcement that google and nasa had achieved, Answer: ['quantum supremacy'], Rouge-1: Score(precision=1.0, recall=0.07692307692307693, fmeasure=0.14285714285714288), Rouge-2: Score(precision=1.0, recall=0.04, fmeasure=0.07692307692307693)
# Question: Is the claim of a definite validity of the claim being investigated?, Answer: ['no'], Rouge-1: Score(precision=0.0, recall=0.0, fmeasure=0.0), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What does the threshold theorem show?, Answer: ['how increasing the number of qubits can mitigate errors'], Rouge-1: Score(precision=1.0, recall=0.375, fmeasure=0.5454545454545454), Rouge-2: Score(precision=1.0, recall=0.34782608695652173, fmeasure=0.5161290322580645)
# Question: What is the main concern of noisy intermediate-scale quantum machines?, Answer: ['reliability'], Rouge-1: Score(precision=1.0, recall=0.038461538461538464, fmeasure=0.07407407407407407), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: Has quantum computing research increased in the public and private sectors?, Answer: ['in recent years'], Rouge-1: Score(precision=1.0, recall=0.1875, fmeasure=0.3157894736842105), Rouge-2: Score(precision=1.0, recall=0.13333333333333333, fmeasure=0.23529411764705882)
# Question: What is the main reason for the growth of quantum-computing start-up, Answer: ['investment dollars are pouring in'], Rouge-1: Score(precision=1.0, recall=0.29411764705882354, fmeasure=0.45454545454545453), Rouge-2: Score(precision=1.0, recall=0.25, fmeasure=0.4)
# Question: What is the nature of quantum computing?, Answer: ['business'], Rouge-1: Score(precision=1.0, recall=0.03125, fmeasure=0.06060606060606061), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: How do computer engineers describe a computer's operation?, Answer: ['classical electrodynamics'], Rouge-1: Score(precision=1.0, recall=0.14285714285714285, fmeasure=0.25), Rouge-2: Score(precision=1.0, recall=0.07692307692307693, fmeasure=0.14285714285714288)
# Question: What is the nature of quantum behavior in "classical" computers?, Answer: ['isolated from their environment'], Rouge-1: Score(precision=1.0, recall=0.12121212121212122, fmeasure=0.21621621621621626), Rouge-2: Score(precision=1.0, recall=0.09375, fmeasure=0.17142857142857143)
# Question: Are quantum mechanical notions irrelevant for program analysis?, Answer: ['largely irrelevant'], Rouge-1: Score(precision=1.0, recall=0.08, fmeasure=0.14814814814814814), Rouge-2: Score(precision=1.0, recall=0.041666666666666664, fmeasure=0.07999999999999999)
# Question: What do quantum programs rely on?, Answer: ['precise control'], Rouge-1: Score(precision=1.0, recall=0.16666666666666666, fmeasure=0.2857142857142857), Rouge-2: Score(precision=1.0, recall=0.09090909090909091, fmeasure=0.16666666666666669)
# Question: How do physicists describe these systems?, Answer: ['mathematically'], Rouge-1: Score(precision=1.0, recall=0.125, fmeasure=0.2222222222222222), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What models do vectors and matrices use?, Answer: ['probability amplitudes'], Rouge-1: Score(precision=1.0, recall=0.09523809523809523, fmeasure=0.17391304347826084), Rouge-2: Score(precision=1.0, recall=0.05, fmeasure=0.09523809523809523)
# Question: What is the process of composing operations in a quantum computer?, Answer: ['programming'], Rouge-1: Score(precision=1.0, recall=0.03333333333333333, fmeasure=0.06451612903225806), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What model of quantum computation describes the computation in terms of a network of quantum logic, Answer: ['prevailing model'], Rouge-1: Score(precision=1.0, recall=0.1111111111111111, fmeasure=0.19999999999999998), Rouge-2: Score(precision=1.0, recall=0.058823529411764705, fmeasure=0.1111111111111111)
# Question: What is the generalization of boolean circuits?, Answer: ['linear-algebraic'], Rouge-1: Score(precision=1.0, recall=0.18181818181818182, fmeasure=0.3076923076923077), Rouge-2: Score(precision=1.0, recall=0.1, fmeasure=0.18181818181818182)
# Question: What is the qubit?, Answer: ['quantum information'], Rouge-1: Score(precision=1.0, recall=0.2, fmeasure=0.33333333333333337), Rouge-2: Score(precision=1.0, recall=0.1111111111111111, fmeasure=0.19999999999999998)
# Question: What is the difference between a bit and a classical bit?, Answer: ['it represents a two-state system'], Rouge-1: Score(precision=1.0, recall=0.2608695652173913, fmeasure=0.41379310344827586), Rouge-2: Score(precision=1.0, recall=0.22727272727272727, fmeasure=0.37037037037037035)
# Question: How is a superposition like a probability distribution over two values?, Answer: ['in one sense'], Rouge-1: Score(precision=1.0, recall=0.21428571428571427, fmeasure=0.35294117647058826), Rouge-2: Score(precision=1.0, recall=0.15384615384615385, fmeasure=0.2666666666666667)
# Question: Can a quantum computation be influenced by both values at once?, Answer: ['inexplicable by either state individually'], Rouge-1: Score(precision=1.0, recall=0.29411764705882354, fmeasure=0.45454545454545453), Rouge-2: Score(precision=1.0, recall=0.25, fmeasure=0.4)
# Question: How does a "superposed" qubit store both values simultaneously?, Answer: ['in this sense'], Rouge-1: Score(precision=1.0, recall=0.3, fmeasure=0.4615384615384615), Rouge-2: Score(precision=1.0, recall=0.2222222222222222, fmeasure=0.3636363636363636)
# Question: How does a two-dimensional vector represent a qubit state?, Answer: ['mathematically'], Rouge-1: Score(precision=1.0, recall=0.1111111111111111, fmeasure=0.19999999999999998), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What do physicists use for quantum mechanical linear algebra?, Answer: ['dirac notation'], Rouge-1: Score(precision=1.0, recall=0.11764705882352941, fmeasure=0.21052631578947367), Rouge-2: Score(precision=1.0, recall=0.0625, fmeasure=0.11764705882352941)
# Question: Why is a qubit a two-state system?, Answer: ['any qubit state takes the form | + |, where |'], Rouge-1: Score(precision=1.0, recall=0.25925925925925924, fmeasure=0.4117647058823529), Rouge-2: Score(precision=1.0, recall=0.23076923076923078, fmeasure=0.375)
# Question: What is the qubit in superposition?, Answer: ['classical bit'], Rouge-1: Score(precision=1.0, recall=0.09523809523809523, fmeasure=0.17391304347826084), Rouge-2: Score(precision=1.0, recall=0.05, fmeasure=0.09523809523809523)
# Question: How does a quantum state vector compare to a classical probability vector?, Answer: ['unlike probabilities, probability amplitudes are not necessarily positive numbers'], Rouge-1: Score(precision=1.0, recall=0.36, fmeasure=0.5294117647058824), Rouge-2: Score(precision=1.0, recall=0.3333333333333333, fmeasure=0.5)
# Question: What is the reason for negative amplitudes?, Answer: ['destructive wave interference'], Rouge-1: Score(precision=1.0, recall=0.42857142857142855, fmeasure=0.6), Rouge-2: Score(precision=1.0, recall=0.3333333333333333, fmeasure=0.5)
# Question: What is the result of a classical bit when a qubit is measured in, Answer: ['the standard basis'], Rouge-1: Score(precision=1.0, recall=0.2, fmeasure=0.33333333333333337), Rouge-2: Score(precision=1.0, recall=0.14285714285714285, fmeasure=0.25)
# Question: What is the born rule?, Answer: ['| + |'], Rouge-1: Score(precision=0.0, recall=0.0, fmeasure=0.0), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is the meaning of the coefficients  and ?, Answer: [''], Rouge-1: Score(precision=0.0, recall=0.0, fmeasure=0.0), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What would happen if the qubit /| + /, Answer: [' would produce either | or | with equal probability'], Rouge-1: Score(precision=1.0, recall=0.5384615384615384, fmeasure=0.7000000000000001), Rouge-2: Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666)
# Question: How does each additional qubit double the dimension of the state space?, Answer: ['each additional qubit doubles the dimension of the state space'], Rouge-1: Score(precision=1.0, recall=1.0, fmeasure=1.0), Rouge-2: Score(precision=1.0, recall=1.0, fmeasure=1.0)
# Question: What is the vector /| + /|?, Answer: ['a two-qubit state'], Rouge-1: Score(precision=1.0, recall=0.21052631578947367, fmeasure=0.34782608695652173), Rouge-2: Score(precision=1.0, recall=0.16666666666666666, fmeasure=0.2857142857142857)
# Question: What is the space of the basis vector?, Answer: ['four-dimensional'], Rouge-1: Score(precision=1.0, recall=0.14285714285714285, fmeasure=0.25), Rouge-2: Score(precision=1.0, recall=0.07692307692307693, fmeasure=0.14285714285714288)
# Question: Why are the two qubits entangled?, Answer: ['their probability amplitudes are correlated'], Rouge-1: Score(precision=1.0, recall=0.19230769230769232, fmeasure=0.32258064516129037), Rouge-2: Score(precision=1.0, recall=0.16, fmeasure=0.2758620689655173)
# Question: Why is it difficult for a classical computer to simulate a quantum system?, Answer: ['in general, the vector space for an n-qubit system is -dimensional'], Rouge-1: Score(precision=1.0, recall=0.35294117647058826, fmeasure=0.5217391304347826), Rouge-2: Score(precision=1.0, recall=0.3333333333333333, fmeasure=0.5)
# Question: How can quantum logic gates be used to manipulate the state of one-qubit quantum, Answer: ['analogous to how classical memory can be manipulated with classical logic gates'], Rouge-1: Score(precision=1.0, recall=0.42857142857142855, fmeasure=0.6), Rouge-2: Score(precision=1.0, recall=0.4074074074074074, fmeasure=0.5789473684210525)
# Question: What is one important gate for classical and quantum computation?, Answer: ['not gate'], Rouge-1: Score(precision=1.0, recall=0.05263157894736842, fmeasure=0.1), Rouge-2: Score(precision=1.0, recall=0.02702702702702703, fmeasure=0.052631578947368425)
# Question: What is the answer to the question?, Answer: ['a syringe'], Rouge-1: Score(precision=0.0, recall=0.0, fmeasure=0.0), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: How can the mathematics of single qubit gates be extended to operate on multi-qu, Answer: ['quantum memories'], Rouge-1: Score(precision=1.0, recall=0.1, fmeasure=0.18181818181818182), Rouge-2: Score(precision=1.0, recall=0.05263157894736842, fmeasure=0.1)
# Question: How can a target qubit be accessed?, Answer: ['gate'], Rouge-1: Score(precision=1.0, recall=0.041666666666666664, fmeasure=0.07999999999999999), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is another way to apply the gate to the target?, Answer: ['if another part of the memory is in a desired state'], Rouge-1: Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), Rouge-2: Score(precision=1.0, recall=0.47619047619047616, fmeasure=0.6451612903225806)
# Question: What is another example of a possible use of a sandbox?, Answer: ['a sandbox'], Rouge-1: Score(precision=0.0, recall=0.0, fmeasure=0.0), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is the cnot gate?, Answer: ['two-qubit quantum memory'], Rouge-1: Score(precision=1.0, recall=0.13793103448275862, fmeasure=0.2424242424242424), Rouge-2: Score(precision=1.0, recall=0.10714285714285714, fmeasure=0.19354838709677416)
# Question: What is the cnot's effect on the second qubit?, Answer: ['the first qubit is in the state'], Rouge-1: Score(precision=1.0, recall=0.2692307692307692, fmeasure=0.42424242424242425), Rouge-2: Score(precision=1.0, recall=0.24, fmeasure=0.3870967741935484)
# Question: What happens to the second qubit?, Answer: ['nothing is done'], Rouge-1: Score(precision=1.0, recall=0.2727272727272727, fmeasure=0.42857142857142855), Rouge-2: Score(precision=1.0, recall=0.2, fmeasure=0.33333333333333337)
# Question: How can a quantum computation be described?, Answer: ['a network of quantum logic gates and measurements'], Rouge-1: Score(precision=1.0, recall=0.47058823529411764, fmeasure=0.6399999999999999), Rouge-2: Score(precision=1.0, recall=0.4375, fmeasure=0.6086956521739131)
# Question: Can measurements be deferred to the end of quantum computation?, Answer: ['any measurement can be deferred to the end of quantum computation'], Rouge-1: Score(precision=1.0, recall=0.2972972972972973, fmeasure=0.4583333333333333), Rouge-2: Score(precision=1.0, recall=0.2777777777777778, fmeasure=0.4347826086956522)
# Question: What does quantum parallelism refer to?, Answer: ['the ability of quantum computers to evaluate a function for multiple input values simultaneously'], Rouge-1: Score(precision=1.0, recall=0.7777777777777778, fmeasure=0.8750000000000001), Rouge-2: Score(precision=1.0, recall=0.7647058823529411, fmeasure=0.8666666666666666)
# Question: How can a quantum system be prepared?, Answer: ['unitary transformation'], Rouge-1: Score(precision=1.0, recall=0.07407407407407407, fmeasure=0.13793103448275862), Rouge-2: Score(precision=1.0, recall=0.038461538461538464, fmeasure=0.07407407407407407)
# Question: What happens when the state is encoded?, Answer: ["the resulting state encodes the function's output values for all input values in the super"], Rouge-1: Score(precision=0.9375, recall=0.625, fmeasure=0.75), Rouge-2: Score(precision=0.9333333333333333, recall=0.6086956521739131, fmeasure=0.7368421052631579)
# Question: What property is key to the speedup of many quantum algorithms?, Answer: ['this property'], Rouge-1: Score(precision=1.0, recall=0.18181818181818182, fmeasure=0.3076923076923077), Rouge-2: Score(precision=1.0, recall=0.1, fmeasure=0.18181818181818182)
# Question: What is the purpose of quantum programming?, Answer: ['further information'], Rouge-1: Score(precision=1.0, recall=0.07692307692307693, fmeasure=0.14285714285714288), Rouge-2: Score(precision=1.0, recall=0.04, fmeasure=0.07692307692307693)
# Question: A toffoli gate is implemented in what diagram?, Answer: ['quantum circuit diagram'], Rouge-1: Score(precision=1.0, recall=0.11538461538461539, fmeasure=0.20689655172413793), Rouge-2: Score(precision=1.0, recall=0.08, fmeasure=0.14814814814814814)
# Question: How can a quantum computation be described?, Answer: ['a network of quantum logic gates and measurements'], Rouge-1: Score(precision=1.0, recall=0.5333333333333333, fmeasure=0.6956521739130436), Rouge-2: Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666)
# Question: Can measurements be deferred to the end of quantum computation?, Answer: ['any measurement can be deferred to the end of quantum computation'], Rouge-1: Score(precision=1.0, recall=0.2972972972972973, fmeasure=0.4583333333333333), Rouge-2: Score(precision=1.0, recall=0.2777777777777778, fmeasure=0.4347826086956522)
# Question: What is the formalism of quantum computation?, Answer: ['network of quantum logic gates'], Rouge-1: Score(precision=1.0, recall=0.15151515151515152, fmeasure=0.2631578947368421), Rouge-2: Score(precision=1.0, recall=0.125, fmeasure=0.2222222222222222)
# Question: What is a universal gate set?, Answer: ['a computer that can run such circuits'], Rouge-1: Score(precision=1.0, recall=0.2413793103448276, fmeasure=0.3888888888888889), Rouge-2: Score(precision=1.0, recall=0.21428571428571427, fmeasure=0.35294117647058826)
# Question: What is the common set of single-qubit gates?, Answer: ['cnot gate'], Rouge-1: Score(precision=1.0, recall=0.11764705882352941, fmeasure=0.21052631578947367), Rouge-2: Score(precision=1.0, recall=0.0625, fmeasure=0.11764705882352941)
# Question: What does this mean for quantum computation?, Answer: ['executing a sequence of single-qubit gates together with cnot gates'], Rouge-1: Score(precision=1.0, recall=0.55, fmeasure=0.7096774193548387), Rouge-2: Score(precision=1.0, recall=0.5263157894736842, fmeasure=0.6896551724137931)
# Question: What is the solovay-kitaev theorem?, Answer: ['finite'], Rouge-1: Score(precision=1.0, recall=0.045454545454545456, fmeasure=0.08695652173913045), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is the process called that decomposes computation into bell state measurements and, Answer: ['quantum gate teleportation'], Rouge-1: Score(precision=1.0, recall=0.08333333333333333, fmeasure=0.15384615384615385), Rouge-2: Score(precision=1.0, recall=0.05714285714285714, fmeasure=0.1081081081081081)
# Question: What is the process called that decomposes computation into a slow continuous, Answer: ['quantum annealing'], Rouge-1: Score(precision=1.0, recall=0.06896551724137931, fmeasure=0.12903225806451613), Rouge-2: Score(precision=1.0, recall=0.03571428571428571, fmeasure=0.0689655172413793)
# Question: What happens when a topological quantum computer decomposes computation into the, Answer: ['braiding of anyons'], Rouge-1: Score(precision=1.0, recall=0.21428571428571427, fmeasure=0.35294117647058826), Rouge-2: Score(precision=1.0, recall=0.15384615384615385, fmeasure=0.2666666666666667)
# Question: The physical implementation of the quantum turing machine is not feasible?, Answer: ['theoretically important'], Rouge-1: Score(precision=1.0, recall=0.11764705882352941, fmeasure=0.21052631578947367), Rouge-2: Score(precision=1.0, recall=0.0625, fmeasure=0.11764705882352941)
# Question: What has been shown to be equivalent to the quantum turing machine?, Answer: ['quantum circuits, one-way quantum computation, adiabatic quantum computation, and top'], Rouge-1: Score(precision=0.9090909090909091, recall=0.19607843137254902, fmeasure=0.3225806451612903), Rouge-2: Score(precision=0.9, recall=0.18, fmeasure=0.3)
# Question: Is this equivalence necessary for quantum computers?, Answer: ['theoretical'], Rouge-1: Score(precision=0.0, recall=0.0, fmeasure=0.0), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is quantum information science?, Answer: ['public key cryptography'], Rouge-1: Score(precision=1.0, recall=0.16666666666666666, fmeasure=0.2857142857142857), Rouge-2: Score(precision=1.0, recall=0.11764705882352941, fmeasure=0.21052631578947367)
# Question: What could quantum-based cryptographic systems be more secure against?, Answer: ['quantum hacking'], Rouge-1: Score(precision=1.0, recall=0.13333333333333333, fmeasure=0.23529411764705882), Rouge-2: Score(precision=1.0, recall=0.07142857142857142, fmeasure=0.13333333333333333)
# Question: What is the most important aspect of finding quantum algorithms?, Answer: ['quantum circuit model'], Rouge-1: Score(precision=1.0, recall=0.15, fmeasure=0.2608695652173913), Rouge-2: Score(precision=1.0, recall=0.10526315789473684, fmeasure=0.1904761904761905)
# Question: Quantum algorithms can be categorized by the type of speedup achieved over corresponding, Answer: ['classical'], Rouge-1: Score(precision=1.0, recall=0.0625, fmeasure=0.11764705882352941), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What quantum algorithms are used for computing discrete logarithms?, Answer: ["shor's algorithm for factoring"], Rouge-1: Score(precision=1.0, recall=0.10869565217391304, fmeasure=0.19607843137254902), Rouge-2: Score(precision=1.0, recall=0.08888888888888889, fmeasure=0.163265306122449)
# Question: What do these algorithms depend on?, Answer: ['the primitive of the quantum fourier transform'], Rouge-1: Score(precision=1.0, recall=0.6363636363636364, fmeasure=0.7777777777777778), Rouge-2: Score(precision=1.0, recall=0.6, fmeasure=0.7499999999999999)
# Question: Has there been a mathematical proof that shows that an equally fast classical algorithm cannot be, Answer: ['no mathematical proof has been found'], Rouge-1: Score(precision=1.0, recall=0.2727272727272727, fmeasure=0.42857142857142855), Rouge-2: Score(precision=1.0, recall=0.23809523809523808, fmeasure=0.3846153846153846)
# Question: What is the source of the information?, Answer: ['self-published source'], Rouge-1: Score(precision=1.0, recall=1.0, fmeasure=1.0), Rouge-2: Score(precision=1.0, recall=1.0, fmeasure=1.0)
# Question: Does the simon's problem give provable speedups?, Answer: ['quantum query model'], Rouge-1: Score(precision=1.0, recall=0.06382978723404255, fmeasure=0.12), Rouge-2: Score(precision=1.0, recall=0.043478260869565216, fmeasure=0.08333333333333333)
# Question: What quantum algorithms are bqp-complete?, Answer: ['quantum algorithms appearing to give super-polynomial speedups'], Rouge-1: Score(precision=1.0, recall=0.18604651162790697, fmeasure=0.3137254901960785), Rouge-2: Score(precision=1.0, recall=0.16666666666666666, fmeasure=0.2857142857142857)
# Question: Why is it unlikely that a quantum algorithm would give a super-poly, Answer: ['no quantum algorithm gives a super-polynomial speedup'], Rouge-1: Score(precision=1.0, recall=0.26666666666666666, fmeasure=0.4210526315789474), Rouge-2: Score(precision=1.0, recall=0.2413793103448276, fmeasure=0.3888888888888889)
# Question: What quantum algorithms give polynomial speedups?, Answer: ["grover's algorithm and amplitude amplification"], Rouge-1: Score(precision=1.0, recall=0.35294117647058826, fmeasure=0.5217391304347826), Rouge-2: Score(precision=1.0, recall=0.3125, fmeasure=0.47619047619047616)
# Question: Are these algorithms widely applicable?, Answer: ['they are widely applicable and thus give speedups for a wide range of problems'], Rouge-1: Score(precision=1.0, recall=0.6363636363636364, fmeasure=0.7777777777777778), Rouge-2: Score(precision=1.0, recall=0.6190476190476191, fmeasure=0.7647058823529412)
# Question: What is grover's algorithm used for?, Answer: ['evaluating nand trees'], Rouge-1: Score(precision=1.0, recall=0.05454545454545454, fmeasure=0.10344827586206896), Rouge-2: Score(precision=1.0, recall=0.037037037037037035, fmeasure=0.07142857142857142)
# Question: What is a notable application of quantum computation?, Answer: ['attacks on cryptographic systems'], Rouge-1: Score(precision=1.0, recall=0.23529411764705882, fmeasure=0.38095238095238093), Rouge-2: Score(precision=1.0, recall=0.1875, fmeasure=0.3157894736842105)
# Question: Is factorization computationally infeasible with an ordinary computer for, Answer: ['large integers'], Rouge-1: Score(precision=1.0, recall=0.058823529411764705, fmeasure=0.1111111111111111), Rouge-2: Score(precision=1.0, recall=0.030303030303030304, fmeasure=0.05882352941176471)
# Question: What is the answer to the question?, Answer: ['g'], Rouge-1: Score(precision=1.0, recall=1.0, fmeasure=1.0), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What are products of two digit primes?, Answer: ['products'], Rouge-1: Score(precision=1.0, recall=0.2, fmeasure=0.33333333333333337), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: How could a quantum computer solve the problem exponentially faster?, Answer: ["using shor's algorithm"], Rouge-1: Score(precision=1.0, recall=0.21052631578947367, fmeasure=0.34782608695652173), Rouge-2: Score(precision=1.0, recall=0.16666666666666666, fmeasure=0.2857142857142857)
# Question: What would happen if a quantum computer could break many cryptographic systems?, Answer: ['there would be a polynomial time (in the number of digits of'], Rouge-1: Score(precision=1.0, recall=0.3, fmeasure=0.4615384615384615), Rouge-2: Score(precision=1.0, recall=0.28205128205128205, fmeasure=0.44000000000000006)
# Question: What are the two main problems with public key ciphers?, Answer: ['difficulty of factoring integers or the discrete logarithm problem'], Rouge-1: Score(precision=1.0, recall=0.28125, fmeasure=0.43902439024390244), Rouge-2: Score(precision=1.0, recall=0.25806451612903225, fmeasure=0.41025641025641024)
# Question: What algorithms could be broken?, Answer: ['rsa, diffie–hellman, and elliptic curve'], Rouge-1: Score(precision=1.0, recall=0.4, fmeasure=0.5714285714285715), Rouge-2: Score(precision=1.0, recall=0.35714285714285715, fmeasure=0.5263157894736842)
# Question: What are these devices used for?, Answer: ['secure web pages, encrypted email, and many other types of data'], Rouge-1: Score(precision=1.0, recall=0.6875, fmeasure=0.8148148148148148), Rouge-2: Score(precision=1.0, recall=0.6666666666666666, fmeasure=0.8)
# Question: What would happen to the privacy of electronic data?, Answer: ['significant ramifications'], Rouge-1: Score(precision=1.0, recall=0.18181818181818182, fmeasure=0.3076923076923077), Rouge-2: Score(precision=1.0, recall=0.1, fmeasure=0.18181818181818182)
# Question: What is a topic of research in the field of post-quantum cryptography, Answer: ['identifying cryptographic systems that may be secure against quantum algorithms'], Rouge-1: Score(precision=1.0, recall=0.45454545454545453, fmeasure=0.625), Rouge-2: Score(precision=1.0, recall=0.42857142857142855, fmeasure=0.6)
# Question: What is the mceliece cryptosystem based on?, Answer: ['coding theory'], Rouge-1: Score(precision=1.0, recall=0.058823529411764705, fmeasure=0.1111111111111111), Rouge-2: Score(precision=1.0, recall=0.030303030303030304, fmeasure=0.05882352941176471)
# Question: Are lattice-based cryptosystems broken by quantum computers?, Answer: ['not known'], Rouge-1: Score(precision=1.0, recall=0.05128205128205128, fmeasure=0.09756097560975609), Rouge-2: Score(precision=1.0, recall=0.02631578947368421, fmeasure=0.05128205128205127)
# Question: What is the difference between grover's algorithm and classical brute force search?, Answer: ["aes- would have the same security against an attack using grover's algorithm"], Rouge-1: Score(precision=1.0, recall=0.18840579710144928, fmeasure=0.3170731707317073), Rouge-2: Score(precision=1.0, recall=0.17647058823529413, fmeasure=0.3)
# Question: What is the most well-known example of a problem that allows for a, Answer: ['polynomial quantum speedup'], Rouge-1: Score(precision=1.0, recall=0.09090909090909091, fmeasure=0.16666666666666669), Rouge-2: Score(precision=1.0, recall=0.0625, fmeasure=0.11764705882352941)
# Question: How is this problem solved?, Answer: ['using queries to the database'], Rouge-1: Score(precision=1.0, recall=0.22727272727272727, fmeasure=0.37037037037037035), Rouge-2: Score(precision=1.0, recall=0.19047619047619047, fmeasure=0.32)
# Question: What is the advantage of grover's algorithm?, Answer: ["it has been shown that grover's algorithm gives the maximal possible probability of finding the desired"], Rouge-1: Score(precision=1.0, recall=0.4722222222222222, fmeasure=0.6415094339622641), Rouge-2: Score(precision=1.0, recall=0.45714285714285713, fmeasure=0.6274509803921569)
# Question: What are the properties of grover's algorithm?, Answer: ['there is no searchable structure in the collection of possible answers'], Rouge-1: Score(precision=1.0, recall=0.10784313725490197, fmeasure=0.19469026548672566), Rouge-2: Score(precision=1.0, recall=0.09900990099009901, fmeasure=0.18018018018018017)
# Question: What is a boolean satiability problem?, Answer: ["grover's algorithm can be applied"], Rouge-1: Score(precision=1.0, recall=0.1935483870967742, fmeasure=0.3243243243243243), Rouge-2: Score(precision=1.0, recall=0.16666666666666666, fmeasure=0.2857142857142857)
# Question: What is an example of a password cracker?, Answer: ['attempt to guess a password'], Rouge-1: Score(precision=1.0, recall=0.29411764705882354, fmeasure=0.45454545454545453), Rouge-2: Score(precision=1.0, recall=0.25, fmeasure=0.4)
# Question: What is the purpose of breaking symmetric ciphers?, Answer: ['government agencies'], Rouge-1: Score(precision=1.0, recall=0.16666666666666666, fmeasure=0.2857142857142857), Rouge-2: Score(precision=1.0, recall=0.09090909090909091, fmeasure=0.16666666666666669)
# Question: Why is quantum simulation important?, Answer: ['quantum computing'], Rouge-1: Score(precision=1.0, recall=0.06451612903225806, fmeasure=0.12121212121212122), Rouge-2: Score(precision=1.0, recall=0.03333333333333333, fmeasure=0.06451612903225806)
# Question: What could quantitative simulation be used to simulate the behavior of atoms and particles?, Answer: ['reactions inside a collider'], Rouge-1: Score(precision=1.0, recall=0.16666666666666666, fmeasure=0.2857142857142857), Rouge-2: Score(precision=1.0, recall=0.13043478260869565, fmeasure=0.23076923076923078)
# Question: What percentage of the global energy output is used for nitrogen fixation?, Answer: ['%'], Rouge-1: Score(precision=0.0, recall=0.0, fmeasure=0.0), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What kind of simulations might be used to understand the production process?, Answer: ['quantum'], Rouge-1: Score(precision=1.0, recall=0.0625, fmeasure=0.11764705882352941), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What does the adiabatic theorem do?, Answer: ['to undertake calculations'], Rouge-1: Score(precision=1.0, recall=0.3, fmeasure=0.4615384615384615), Rouge-2: Score(precision=1.0, recall=0.2222222222222222, fmeasure=0.3636363636363636)
# Question: What happens when a system is placed in the ground state for a simple , Answer: ['slowly evolves to a more complicated hamiltonian whose ground state represents the'], Rouge-1: Score(precision=1.0, recall=0.3870967741935484, fmeasure=0.5581395348837209), Rouge-2: Score(precision=1.0, recall=0.36666666666666664, fmeasure=0.5365853658536585)
# Question: What is the adiabatic theorem?, Answer: ['state that if the evolution is slow enough the system will stay in its ground state at all'], Rouge-1: Score(precision=1.0, recall=0.72, fmeasure=0.8372093023255813), Rouge-2: Score(precision=1.0, recall=0.7083333333333334, fmeasure=0.8292682926829268)
# Question: What kind of optimization is useful for solving computational biology problems?, Answer: ['adiabatic'], Rouge-1: Score(precision=1.0, recall=0.1, fmeasure=0.18181818181818182), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: Why do some hope in developing quantum algorithms?, Answer: ['speed up machine learning tasks'], Rouge-1: Score(precision=1.0, recall=0.14705882352941177, fmeasure=0.25641025641025644), Rouge-2: Score(precision=1.0, recall=0.12121212121212122, fmeasure=0.21621621621621626)
# Question: What is the speedup of the quantum algorithm for linear systems of equations?, Answer: ['classical counterparts'], Rouge-1: Score(precision=1.0, recall=0.06896551724137931, fmeasure=0.12903225806451613), Rouge-2: Score(precision=1.0, recall=0.03571428571428571, fmeasure=0.0689655172413793)
# Question: What is the latest research to explore the use of quantum annealing hardware?, Answer: ['some research groups have recently explored the use of quantum annealing hardware for training boltz'], Rouge-1: Score(precision=0.9333333333333333, recall=0.7, fmeasure=0.8), Rouge-2: Score(precision=0.9285714285714286, recall=0.6842105263157895, fmeasure=0.7878787878787878)
# Question: What is the role of deep generative chemistry models in drug discovery?, Answer: ['powerful tools'], Rouge-1: Score(precision=1.0, recall=0.16666666666666666, fmeasure=0.2857142857142857), Rouge-2: Score(precision=1.0, recall=0.09090909090909091, fmeasure=0.16666666666666669)
# Question: What is the main problem with drug-like molecules?, Answer: ['massive size and complexity'], Rouge-1: Score(precision=0.75, recall=0.10344827586206896, fmeasure=0.18181818181818182), Rouge-2: Score(precision=0.6666666666666666, recall=0.07142857142857142, fmeasure=0.12903225806451613)
# Question: Are computers able to solve complex quantum many-body problems?, Answer: ['naturally good'], Rouge-1: Score(precision=1.0, recall=0.09090909090909091, fmeasure=0.16666666666666669), Rouge-2: Score(precision=1.0, recall=0.047619047619047616, fmeasure=0.0909090909090909)
# Question: What is the possibility that quantum gans may be developed into ultimate generative , Answer: ['quantum-enhanced generative models'], Rouge-1: Score(precision=1.0, recall=0.19047619047619047, fmeasure=0.32), Rouge-2: Score(precision=1.0, recall=0.15, fmeasure=0.2608695652173913)
# Question: What is adiabatic quantum computers?, Answer: ['wafer'], Rouge-1: Score(precision=1.0, recall=0.05, fmeasure=0.09523809523809523), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is the list of requirements for a quantum computer?, Answer: ['sourcing parts'], Rouge-1: Score(precision=1.0, recall=0.09523809523809523, fmeasure=0.17391304347826084), Rouge-2: Score(precision=1.0, recall=0.05, fmeasure=0.09523809523809523)
# Question: What is required to make superconducting quantum computers?, Answer: ['helium-, a nuclear research byproduct'], Rouge-1: Score(precision=1.0, recall=0.17857142857142858, fmeasure=0.30303030303030304), Rouge-2: Score(precision=1.0, recall=0.14814814814814814, fmeasure=0.25806451612903225)
# Question: What is the need for the coordination of a large number of electrical signals?, Answer: ['the control of multi-qubit systems'], Rouge-1: Score(precision=1.0, recall=0.25, fmeasure=0.4), Rouge-2: Score(precision=1.0, recall=0.21739130434782608, fmeasure=0.3571428571428571)
# Question: What has led to the development of quantum controllers?, Answer: ['interfacing with the qubits'], Rouge-1: Score(precision=1.0, recall=0.26666666666666666, fmeasure=0.4210526315789474), Rouge-2: Score(precision=1.0, recall=0.21428571428571427, fmeasure=0.35294117647058826)
# Question: What is an additional challenge to scaling systems to support a growing number of qubit, Answer: ['scaling'], Rouge-1: Score(precision=1.0, recall=0.07142857142857142, fmeasure=0.13333333333333333), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is one of the biggest challenges in constructing quantum computers?, Answer: ['controlling or removing quantum decoherence'], Rouge-1: Score(precision=1.0, recall=0.3125, fmeasure=0.47619047619047616), Rouge-2: Score(precision=1.0, recall=0.26666666666666666, fmeasure=0.4210526315789474)
# Question: How does the system deal with external influences?, Answer: ['interactions with the external world'], Rouge-1: Score(precision=1.0, recall=0.25, fmeasure=0.4), Rouge-2: Score(precision=1.0, recall=0.21052631578947367, fmeasure=0.34782608695652173)
# Question: Do there exist other sources of decoherence?, Answer: ['other sources of decoherence'], Rouge-1: Score(precision=1.0, recall=0.5714285714285714, fmeasure=0.7272727272727273), Rouge-2: Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666)
# Question: What are some examples of the physical system used to implement qubits?, Answer: ['quantum gates'], Rouge-1: Score(precision=1.0, recall=0.09090909090909091, fmeasure=0.16666666666666669), Rouge-2: Score(precision=1.0, recall=0.047619047619047616, fmeasure=0.0909090909090909)
# Question: Is coherence irreversible?, Answer: ['non-unitary'], Rouge-1: Score(precision=1.0, recall=0.09523809523809523, fmeasure=0.17391304347826084), Rouge-2: Score(precision=1.0, recall=0.05, fmeasure=0.09523809523809523)
# Question: What is the transverse relaxation time also called?, Answer: ['dephasing time'], Rouge-1: Score(precision=1.0, recall=0.06666666666666667, fmeasure=0.125), Rouge-2: Score(precision=1.0, recall=0.034482758620689655, fmeasure=0.06666666666666667)
# Question: What is the current state of quantum computers?, Answer: ['qubits'], Rouge-1: Score(precision=1.0, recall=0.043478260869565216, fmeasure=0.08333333333333333), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is the main argument for ionizing radiation?, Answer: ['cosmic rays can nevertheless cause certain systems to decohere within milliseconds'], Rouge-1: Score(precision=1.0, recall=0.5789473684210527, fmeasure=0.7333333333333334), Rouge-2: Score(precision=1.0, recall=0.5555555555555556, fmeasure=0.7142857142857143)
# Question: What is the result of trying to maintain the state of qubits for long enough, Answer: ['time-consuming tasks may render some quantum algorithms inoperable'], Rouge-1: Score(precision=1.0, recall=0.3, fmeasure=0.4615384615384615), Rouge-2: Score(precision=1.0, recall=0.27586206896551724, fmeasure=0.4324324324324324)
# Question: Are optical pulse shaping and pulse shaping more difficult or difficult for optical approaches?, Answer: ['difficult'], Rouge-1: Score(precision=1.0, recall=0.03571428571428571, fmeasure=0.0689655172413793), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is the general rule of error rates?, Answer: ['proportional'], Rouge-1: Score(precision=1.0, recall=0.037037037037037035, fmeasure=0.07142857142857142), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is the threshold theorem?, Answer: ['error rate'], Rouge-1: Score(precision=1.0, recall=0.06896551724137931, fmeasure=0.12903225806451613), Rouge-2: Score(precision=1.0, recall=0.03571428571428571, fmeasure=0.0689655172413793)
# Question: What is the advantage of using error correction schemes to correct errors faster than decoher, Answer: ['decoherence'], Rouge-1: Score(precision=1.0, recall=0.038461538461538464, fmeasure=0.07407407407407407), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ...
# Question: What is the term for quantum supremacy?, Answer: ['a term coined by john preskill'], Rouge-1: Score(precision=1.0, recall=0.17142857142857143, fmeasure=0.2926829268292683), Rouge-2: Score(precision=1.0, recall=0.14705882352941177, fmeasure=0.25641025641025644)
# Question: What is the problem with the quantum supremacy test?, Answer: ['the problem need not be useful'], Rouge-1: Score(precision=1.0, recall=0.3157894736842105, fmeasure=0.4799999999999999), Rouge-2: Score(precision=1.0, recall=0.2777777777777778, fmeasure=0.4347826086956522)
# Question: What was the first claim to have achieved quantum supremacy?, Answer: ['nasa'], Rouge-1: Score(precision=1.0, recall=0.021739130434782608, fmeasure=0.042553191489361694), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: Has summit been able to perform samples much faster than claimed?, Answer: ['ibm has stated that summit can perform samples much faster than claimed'], Rouge-1: Score(precision=1.0, recall=0.24489795918367346, fmeasure=0.39344262295081966), Rouge-2: Score(precision=1.0, recall=0.22916666666666666, fmeasure=0.37288135593220334)
# Question: What did the group at ustc do to demonstrate quantum supremacy?, Answer: ['implemented a type of boson sampling on photons with a photonic quantum computer'], Rouge-1: Score(precision=1.0, recall=0.5416666666666666, fmeasure=0.7027027027027027), Rouge-2: Score(precision=1.0, recall=0.5217391304347826, fmeasure=0.6857142857142856)
# Question: What do the authors of the paper claim about the computational time of a classical contemporary, Answer: ['the number of samples their quantum processor can generate in seconds'], Rouge-1: Score(precision=1.0, recall=0.3793103448275862, fmeasure=0.5499999999999999), Rouge-2: Score(precision=1.0, recall=0.35714285714285715, fmeasure=0.5263157894736842)
# Question: What was the name of the ibm eagle microprocessor, Answer: ['ibm'], Rouge-1: Score(precision=1.0, recall=0.06666666666666667, fmeasure=0.125), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: Why do some researchers believe quantum computers could never be built?, Answer: ['skepticism'], Rouge-1: Score(precision=1.0, recall=0.034482758620689655, fmeasure=0.06666666666666667), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What did Bill unruh doubt about quantum computers?, Answer: ['practicality'], Rouge-1: Score(precision=1.0, recall=0.07692307692307693, fmeasure=0.14285714285714288), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What argument did paul davies make?, Answer: ['a -qubit computer would even come into conflict with the cosmological information bound'], Rouge-1: Score(precision=1.0, recall=0.5909090909090909, fmeasure=0.7428571428571429), Rouge-2: Score(precision=1.0, recall=0.5714285714285714, fmeasure=0.7272727272727273)
# Question: What do skeptics like gil kalai doubt about, Answer: ['quantum supremacy'], Rouge-1: Score(precision=1.0, recall=0.16666666666666666, fmeasure=0.2857142857142857), Rouge-2: Score(precision=1.0, recall=0.09090909090909091, fmeasure=0.16666666666666669)
# Question: What is the opinion of physicist mikhail dyako, Answer: ['skepticism'], Rouge-1: Score(precision=1.0, recall=0.018867924528301886, fmeasure=0.037037037037037035), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is the simple answer to your question?, Answer: ['a simple answer'], Rouge-1: Score(precision=0.6666666666666666, recall=0.5, fmeasure=0.5714285714285715), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: Do you ever think you will be able to answer the question?, Answer: ['no'], Rouge-1: Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: How many candidates are being pursued for implementing a quantum computer?, Answer: ['many different candidates'], Rouge-1: Score(precision=1.0, recall=0.07317073170731707, fmeasure=0.13636363636363635), Rouge-2: Score(precision=1.0, recall=0.05, fmeasure=0.09523809523809523)
# Question: What is computability theory?, Answer: ['any computational problem solvable by a classical computer is also solvable by a'], Rouge-1: Score(precision=1.0, recall=0.6842105263157895, fmeasure=0.8125000000000001), Rouge-2: Score(precision=1.0, recall=0.6666666666666666, fmeasure=0.8)
# Question: Why is it believed that all physical phenomena can be described using quantum mechanics?, Answer: ['intuitively, this is because it is believed that all physical phenomena, including the operation of classical'], Rouge-1: Score(precision=1.0, recall=0.5333333333333333, fmeasure=0.6956521739130436), Rouge-2: Score(precision=1.0, recall=0.5172413793103449, fmeasure=0.6818181818181819)
# Question: What is the opposite of quantum computers?, Answer: ['classical'], Rouge-1: Score(precision=1.0, recall=0.06666666666666667, fmeasure=0.125), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: How can one simulate quantum computers?, Answer: ['manually with just some paper and a pen'], Rouge-1: Score(precision=1.0, recall=0.36363636363636365, fmeasure=0.5333333333333333), Rouge-2: Score(precision=1.0, recall=0.3333333333333333, fmeasure=0.5)
# Question: How can a quantum computer be simulated by a turing machine?, Answer: ['formally'], Rouge-1: Score(precision=1.0, recall=0.08333333333333333, fmeasure=0.15384615384615385), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is the meaning of quantum computers?, Answer: ['provide no additional power over classical computers'], Rouge-1: Score(precision=1.0, recall=0.4375, fmeasure=0.6086956521739131), Rouge-2: Score(precision=1.0, recall=0.4, fmeasure=0.5714285714285715)
# Question: Does the existence of quantum computers disprove the church-turing thesis?, Answer: ['no'], Rouge-1: Score(precision=0.0, recall=0.0, fmeasure=0.0), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: Are quantum computers able to solve problems that classical computers cannot?, Answer: ['yes'], Rouge-1: Score(precision=0.0, recall=0.0, fmeasure=0.0), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is known about quantum computers?, Answer: ['quantum computers can efficiently factor integers'], Rouge-1: Score(precision=1.0, recall=0.25, fmeasure=0.4), Rouge-2: Score(precision=1.0, recall=0.21739130434782608, fmeasure=0.3571428571428571)
# Question: What is the class of problems that can be efficiently solved by a quantum computer with, Answer: ['bounded error'], Rouge-1: Score(precision=1.0, recall=0.08, fmeasure=0.14814814814814814), Rouge-2: Score(precision=1.0, recall=0.041666666666666664, fmeasure=0.07999999999999999)
# Question: What is the bqp class of problems?, Answer: ['polynomial-time quantum turing machine'], Rouge-1: Score(precision=1.0, recall=0.19230769230769232, fmeasure=0.32258064516129037), Rouge-2: Score(precision=1.0, recall=0.16, fmeasure=0.2758620689655173)
# Question: What is bqp the quantum counterpart to?, Answer: ['bpp'], Rouge-1: Score(precision=1.0, recall=0.02857142857142857, fmeasure=0.05555555555555556), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: Is it known that quantum computers are more powerful than classical computers?, Answer: ['intuitively'], Rouge-1: Score(precision=1.0, recall=0.037037037037037035, fmeasure=0.07142857142857142), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is the relationship of bqp to p, np,, Answer: ['the suspected relationship of bqp to several classical complexity classes'], Rouge-1: Score(precision=1.0, recall=0.43478260869565216, fmeasure=0.6060606060606061), Rouge-2: Score(precision=1.0, recall=0.4090909090909091, fmeasure=0.5806451612903226)
# Question: What is known about quantum computers?, Answer: ['deterministic classical computer'], Rouge-1: Score(precision=1.0, recall=0.05660377358490566, fmeasure=0.10714285714285715), Rouge-2: Score(precision=1.0, recall=0.038461538461538464, fmeasure=0.07407407407407407)
# Question: Is bqp a strict superset of p?, Answer: ['bqp is a strict superset of p'], Rouge-1: Score(precision=1.0, recall=0.21875, fmeasure=0.358974358974359), Rouge-2: Score(precision=1.0, recall=0.1935483870967742, fmeasure=0.3243243243243243)
# Question: Are integer factorization and the discrete logarithm problem suspected to be outside, Answer: ['p'], Rouge-1: Score(precision=1.0, recall=0.043478260869565216, fmeasure=0.08333333333333333), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# Question: What is little known about the relationship of bqp to np?, Answer: ['some np problems that are believed not to be in p'], Rouge-1: Score(precision=1.0, recall=0.2619047619047619, fmeasure=0.41509433962264153), Rouge-2: Score(precision=1.0, recall=0.24390243902439024, fmeasure=0.39215686274509803)
# Question: Is there a problem that is not efficiently solvable by a quantum, Answer: ['checkable problems'], Rouge-1: Score(precision=1.0, recall=0.08333333333333333, fmeasure=0.15384615384615385), Rouge-2: Score(precision=1.0, recall=0.043478260869565216, fmeasure=0.08333333333333333)
# Question: Is it suspected that bqp is disjointed from the class, Answer: ['it is also suspected that bqp is disjointed from the class'], Rouge-1: Score(precision=1.0, recall=0.24444444444444444, fmeasure=0.39285714285714285), Rouge-2: Score(precision=1.0, recall=0.22727272727272727, fmeasure=0.37037037037037035)
# Question: What is the relationship of bqp to the basic classical complexity classes?, Answer: ['subclass of pspace'], Rouge-1: Score(precision=1.0, recall=0.06976744186046512, fmeasure=0.13043478260869565), Rouge-2: Score(precision=1.0, recall=0.047619047619047616, fmeasure=0.0909090909090909)
# Question: What has been speculated about the possibility of computers being made faster?, Answer: ['further advances in physics'], Rouge-1: Score(precision=1.0, recall=0.26666666666666666, fmeasure=0.4210526315789474), Rouge-2: Score(precision=1.0, recall=0.21428571428571427, fmeasure=0.35294117647058826)
# Question: What has been shown about a non-local hidden variable quantum computer?, Answer: ['based on bohmian mechanics'], Rouge-1: Score(precision=1.0, recall=0.09523809523809523, fmeasure=0.17391304347826084), Rouge-2: Score(precision=1.0, recall=0.07317073170731707, fmeasure=0.13636363636363635)
# Question: Would quantum computers be able to solve np-complete problems in polynom, Answer: ['no search method'], Rouge-1: Score(precision=0.6666666666666666, recall=0.1111111111111111, fmeasure=0.1904761904761905), Rouge-2: Score(precision=0.5, recall=0.058823529411764705, fmeasure=0.10526315789473684)
# Question: What kind of quantum gravity theory may allow faster computers to be built?, Answer: ['quantum gravity'], Rouge-1: Score(precision=1.0, recall=0.1, fmeasure=0.18181818181818182), Rouge-2: Score(precision=1.0, recall=0.05263157894736842, fmeasure=0.1)
# Question: Is computation a problem in physical theories?, Answer: ['no obvious way to describe what it means for an observer to submit input to a computer'], Rouge-1: Score(precision=1.0, recall=0.2982456140350877, fmeasure=0.45945945945945943), Rouge-2: Score(precision=1.0, recall=0.2857142857142857, fmeasure=0.4444444444444445)
# Question: What Wikimedia Commons has media related to quantum computer?, Answer: ['wikimedia commons'], Rouge-1: Score(precision=1.0, recall=0.25, fmeasure=0.4), Rouge-2: Score(precision=1.0, recall=0.14285714285714285, fmeasure=0.25)
# Question: What is the name of the website that has resources for learning about quantum computing?, Answer: ['wikiversity'], Rouge-1: Score(precision=1.0, recall=0.125, fmeasure=0.2222222222222222), Rouge-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# {'Question': ['Answer', 'Sentence', 'Rouge-1(Precision)', 'Rouge-1(Recall)', 'Rouge-1(fmeasure)', 'Rouge-2(Precision)', 'Rouge-2(Recall)', 'Rouge-2(fmeasure)'], 'What is a quantum computer?': ['a computer that exploits quantum mechanical phenomena', 'technology that uses quantum mechanics\n ibm q system one, a quantum computer with  superconducting qubits\na quantum computer is a computer that exploits quantum mechanical phenomena', 1.0, 0.2692307692307692, 0.42424242424242425, 1.0, 0.24, 0.3870967741935484], 'Quantum computing leverages the behavior of particles and waves?': ['physical matter exhibits properties', 'at small scales, physical matter exhibits properties of both particles and waves, and quantum computing leverages this behavior using specialized hardware', 1.0, 0.19047619047619047, 0.32, 1.0, 0.15, 0.2608695652173913], 'What is the problem with quantum computers?': ['a scalable quantum computer could perform some calculations exponentially faster than any modern "classical', 'classical physics cannot explain the operation of these quantum devices, and a scalable quantum computer could perform some calculations exponentially faster than any modern "classical" computer', 1.0, 0.5384615384615384, 0.7000000000000001, 1.0, 0.52, 0.6842105263157895], 'What could a quantum computer do?': ['perform physical simulations', 'in particular, a large-scale quantum computer could break widely used encryption schemes and aid physicists in performing physical simulations; however, the current state of the art is still largely experimental and impractical', 1.0, 0.09090909090909091, 0.16666666666666669, 1.0, 0.0625, 0.11764705882352941], 'What is the qubit?': ['quantum information', 'the qubit serves as the basic unit of quantum information', 1.0, 0.2, 0.33333333333333337, 1.0, 0.1111111111111111, 0.19999999999999998], 'Can a qubit exist in a superposition of its two "basis': ['unlike a classical bit', 'unlike a classical bit, a qubit can exist in a superposition of its two "basis" states, which loosely means that it is in both states simultaneously', 1.0, 0.15384615384615385, 0.2666666666666667, 1.0, 0.12, 0.21428571428571425], 'What is the result of a classical bit?': ['probabilistic', 'when measuring a qubit, the result is a probabilistic output of a classical bit', 1.0, 0.07142857142857142, 0.13333333333333333, 0.0, 0.0, 0.0], 'What is the effect of wave interference on the measurement results?': ['amplify', 'if a quantum computer manipulates the qubit in a particular way, wave interference effects can amplify the desired measurement results', 1.0, 0.05, 0.09523809523809523, 0.0, 0.0, 0.0], 'What is the process of designing quantum algorithms?': ['create procedures that allow a quantum computer to perform calculations efficiently', 'the design of quantum algorithms involves creating procedures that allow a quantum computer to perform calculations efficiently', 1.0, 0.6470588235294118, 0.7857142857142858, 1.0, 0.625, 0.7692307692307693], 'What has proved challenging in the past?': ['high-quality qubits', 'physically engineering high-quality qubits has proven challenging', 1.0, 0.375, 0.5454545454545454, 1.0, 0.2857142857142857, 0.4444444444444445], 'What happens to a physical qubit if it is not isolated from its environment': ['suffers from quantum decoherence', 'if a physical qubit is not sufficiently isolated from its environment, it suffers from quantum decoherence, introducing noise into calculations', 1.0, 0.2, 0.33333333333333337, 1.0, 0.15789473684210525, 0.2727272727272727], 'What has been the goal of qubits with longer coherence times and lower': ['error rates', 'national governments have invested heavily in experimental research that aims to develop scalable qubits with longer coherence times and lower error rates', 1.0, 0.09090909090909091, 0.16666666666666669, 1.0, 0.047619047619047616, 0.0909090909090909], 'What are the two most promising technologies?': ['superconductors (which isolate an electrical current by eli ...

# %%
# Step 9: Save to CSV
# Save to CSV
import pandas as pd

# Convert dictionary to Pandas DataFrame
df = pd.DataFrame(qa_dict_t5)

# Save DataFrame to CSV file
df.to_csv('qa_T5.csv', index=False)

# %% [markdown]
# ## Conclusion
# Without much time and knowledge in NLP, I was limited in what I can achieve, but just my humble efforts here.
#
# Here are some of the observation from the finding:
# 1. For simpler questions, the model generated the correct output and is factually correct.
# 2. For more complicated and open-ended questions, the model does seem to struggle. From what I can infer, it is probably due to quality of the context. If the question is generated poorly from the context, it will roll over and affect the answer as well.
# 3. Some of the question and answers are not of good quality which may be due to the sentence given as context. More could have been done, alternatively, if I was using this for some use case, I would just remove those with a poorer score and keep to better ones.
# 4. The Rouge Score
#   - The precision is generally high and recall varies, but is significantly lower than the precision.
#   - This indicates that the model is very conservative and does not label true positives
#   - The pros and cons would depend, but if we are pruning by recall score, this will allow us to have a more accurate model, but at a cost of less information available.
#   - As a result, when looking at the fmeasure, there are scores that are on both ends of the spectrum. However, with a median of around `0.26` and mean of `0.31`, there leaves more to be desired.
#
#
#
# There would be some things that I would like to improve on.
# 1. Better regex and data clean. This is to ensure that no weirdly strung sentences end up in the data.
# 2. Qualitative checks. The sentences are split with punctuation and the regex is was only capable of removing some of the standard clutters like special character and spaces. It would be nice to be able to handle some qualitative work, where there would be a filter to remove sentences that does not bring any value or are not relevant to our scenario.
# 3. Better question generation models that would make the questions have a little context at least. For example, "What the Germans do in the war". Without the context of World War 2, and the sentence, The machine may give answers to Germanic wars from 17th to 19th century.
# 4. Fine tune the model. I did not have the bandwidth to research and figure out how to do so. With more time and energy to spend on this project, I would be able to figure out the settings to do fine-tuning.
